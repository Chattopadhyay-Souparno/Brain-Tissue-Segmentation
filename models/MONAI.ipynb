# %% [markdown]
# # SwinUNETR Unet

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Install MONAI and other dependencies
# !pip install monai==0.9.1
# !pip install nibabel
# !pip install SimpleITK

# Import necessary libraries
import os
import glob
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import nibabel as nib
import SimpleITK as sitk

import monai
from monai.data import CacheDataset, DataLoader
from monai.transforms import (
    Compose, LoadImaged, EnsureChannelFirstd, ScaleIntensityd,
    RandSpatialCropd, RandFlipd, RandRotate90d, SpatialCropd,
    EnsureTyped, MapTransform, Transform
)
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.networks.nets import SwinUNETR  # Changed from AttentionUnet to SwinUNETR
from monai.utils import set_determinism

from google.colab import drive
drive.mount("/content/drive")

# Set determinism for reproducibility
set_determinism(seed=0)

# Define the data directory
data_dir = '/content/drive/MyDrive/Dataset_Final/'  # Update this path if different

# Function to load data dictionaries
def get_data_dicts(data_dir, set_name):
    data_pattern = os.path.join(data_dir, set_name, 'IBSR_*')
    subject_dirs = glob.glob(data_pattern)
    data_dicts = []

    for subject_dir in subject_dirs:
        subject_name = os.path.basename(subject_dir)
        img_file = os.path.join(subject_dir, '{}.nii.gz'.format(subject_name))
        seg_file = os.path.join(subject_dir, '{}_seg.nii.gz'.format(subject_name))
        data_dicts.append({'image': img_file, 'label': seg_file})

    # Debug: Print shapes of first few images
    if len(data_dicts) > 0:
        sample_image = nib.load(data_dicts[0]['image']).get_fdata()
        sample_label = nib.load(data_dicts[0]['label']).get_fdata()
        print(f"Sample image shape: {sample_image.shape}")
        print(f"Sample label shape: {sample_label.shape}")

    return data_dicts

# Get training and validation data dictionaries
train_files = get_data_dicts(data_dir, 'Training_Set')
val_files = get_data_dicts(data_dir, 'Validation_Set')

# Custom Transform: CenterSpatialCropd
class CenterSpatialCropd(Transform):
    def __init__(self, keys, roi_size):
        self.keys = keys
        self.roi_size = roi_size

    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            img = d[key]
            spatial_shape = img.shape[1:]  # Assuming (C, D, H, W)
            center = [dim // 2 for dim in spatial_shape]
            # Apply SpatialCropd with roi_center
            crop = SpatialCropd(keys=[key], roi_size=self.roi_size, roi_center=center)
            d = crop(d)
        return d

# Define training transformations
train_transforms = Compose([
    LoadImaged(keys=['image', 'label']),
    EnsureChannelFirstd(keys=['image', 'label']),
    ScaleIntensityd(keys=['image']),
    RandSpatialCropd(keys=['image', 'label'], roi_size=[96, 96, 96], random_size=False),
    RandFlipd(keys=['image', 'label'], prob=0.5, spatial_axis=0),
    RandRotate90d(keys=['image', 'label'], prob=0.5, max_k=3),
    EnsureTyped(keys=['image', 'label']),
])

# Define validation transformations with deterministic spatial cropping
val_transforms = Compose([
    LoadImaged(keys=['image', 'label']),
    EnsureChannelFirstd(keys=['image', 'label']),
    ScaleIntensityd(keys=['image']),
    CenterSpatialCropd(keys=['image', 'label'], roi_size=[96, 96, 96]),  # Deterministic center crop
    EnsureTyped(keys=['image', 'label']),
])

# Use CacheDataset for faster data loading
num_workers = 4  # Adjust based on your system's capabilities

# Create training and validation datasets and dataloaders
train_ds = CacheDataset(
    data=train_files,
    transform=train_transforms,
    cache_rate=1.0,  # Cache all data
    num_workers=num_workers
)
train_loader = DataLoader(train_ds, batch_size=1, shuffle=True, num_workers=num_workers)

val_ds = CacheDataset(
    data=val_files,
    transform=val_transforms,
    cache_rate=1.0,  # Cache all data
    num_workers=num_workers
)
val_loader = DataLoader(val_ds, batch_size=1, shuffle=False, num_workers=num_workers)

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the model (using MONAI's SwinUNETR)
try:
    model = SwinUNETR(
        in_channels=1,
        out_channels=4,               # Number of classes
        img_size=[96, 96, 96],        # Should match the ROI size used in transforms
        feature_size=48,              # Base number of features
        use_checkpoint=False,         # Disable checkpointing if unsupported
    ).to(device)
    print("SwinUNETR model instantiated successfully!")
except TypeError as e:
    print(f"Error during model instantiation: {e}")
    print("Please refer to MONAI v0.9.1 documentation for supported parameters.")
    raise e  # Re-raise the exception after informing the user

# Optionally, load pre-trained weights if available
# model.load_state_dict(torch.load('/path/to/pretrained/model.pth'))

# Define loss function and optimizer
loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# Define metric for evaluation without to_onehot_y and softmax
dice_metric = DiceMetric(
    include_background=True,
    reduction="mean",
    get_not_nans=False,
)

# Training loop
max_epochs = 2000
val_interval = 2  # Do validation every 2 epochs
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []

for epoch in range(max_epochs):
    print('-' * 10)
    print('Epoch {}/{}'.format(epoch + 1, max_epochs))
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = batch_data['image'].to(device), batch_data['label'].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print('{}/{}, train_loss: {:.4f}'.format(step, len(train_loader), loss.item()))
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print('Epoch {} average loss: {:.4f}'.format(epoch + 1, epoch_loss))

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            metric_sum = 0.0
            metric_count = 0
            for val_data in val_loader:
                val_images = val_data['image'].to(device)
                val_labels = val_data['label'].to(device)
                val_outputs = model(val_images)

                # Apply softmax to model outputs
                val_outputs_softmax = F.softmax(val_outputs, dim=1)

                # One-hot encode labels
                val_labels_onehot = F.one_hot(val_labels.squeeze(1).long(), num_classes=4)  # Shape: (1, H, W, D, C)
                val_labels_onehot = val_labels_onehot.permute(0, 4, 1, 2, 3).float()       # Shape: (1, C, H, W, D)

                # Update DiceMetric
                dice_metric(y_pred=val_outputs_softmax, y=val_labels_onehot)

                metric_count += 1

            # Compute the mean dice score
            metric = dice_metric.aggregate().item()
            dice_metric.reset()
            metric_values.append(metric)

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), 'best_metric_model_SWIN.pth')
                print('Saved new best metric model')
            print('Current epoch: {} current mean dice: {:.4f} best mean dice: {:.4f} at epoch {}'.format(
                epoch + 1, metric, best_metric, best_metric_epoch))

print('Training completed, best_metric: {:.4f} at epoch: {}'.format(best_metric, best_metric_epoch))

# Load the best model for evaluation
model.load_state_dict(torch.load('best_metric_model_SWINUNETR.pth'))

# Evaluation functions
def compute_dice_coefficient(in1, in2, label=1):
    in1 = in1 == label
    in2 = in2 == label
    intersection = np.logical_and(in1, in2).sum()
    volumes = in1.sum() + in2.sum()
    if volumes == 0:
        return np.NaN
    else:
        return 2. * intersection / volumes

def compute_hausdorff_distance(in1, in2, label=1):
    in1 = (in1 == label).astype(np.uint8)
    in2 = (in2 == label).astype(np.uint8)
    in1_sitk = sitk.GetImageFromArray(in1)
    in2_sitk = sitk.GetImageFromArray(in2)
    hausdorff_distance_filter = sitk.HausdorffDistanceImageFilter()
    hausdorff_distance_filter.Execute(in1_sitk, in2_sitk)
    return hausdorff_distance_filter.GetHausdorffDistance()

def compute_volumetric_difference(in1, in2, label=1):
    in1 = in1 == label
    in2 = in2 == label
    vol1 = in1.sum()
    vol2 = in2.sum()
    if vol1 + vol2 == 0:
        return np.NaN
    else:
        return abs(vol1 - vol2) / (vol1 + vol2)

# Evaluate on validation data
model.eval()
dice_scores = {i: [] for i in range(4)}  # Assuming 4 classes
hausdorff_distances = {i: [] for i in range(4)}
volumetric_differences = {i: [] for i in range(4)}

with torch.no_grad():
    for val_data in val_loader:
        val_images = val_data['image'].to(device)
        val_labels = val_data['label'].cpu().numpy()
        outputs = model(val_images)
        outputs = torch.argmax(F.softmax(outputs, dim=1), dim=1).cpu().numpy()  # Shape: (1, H, W, D)

        for label in range(4):  # For each class
            dice = compute_dice_coefficient(outputs[0], val_labels[0][0], label=label)
            hd = compute_hausdorff_distance(outputs[0], val_labels[0][0], label=label)
            vd = compute_volumetric_difference(outputs[0], val_labels[0][0], label=label)
            if not np.isnan(dice):
                dice_scores[label].append(dice)
            if not np.isnan(hd):
                hausdorff_distances[label].append(hd)
            if not np.isnan(vd):
                volumetric_differences[label].append(vd)

# Compute average metrics per class
for label in range(4):
    avg_dice = np.mean(dice_scores[label]) if dice_scores[label] else np.NaN
    avg_hd = np.mean(hausdorff_distances[label]) if hausdorff_distances[label] else np.NaN
    avg_vd = np.mean(volumetric_differences[label]) if volumetric_differences[label] else np.NaN
    print(f"Class {label}:")
    print(f"\tDice Coefficient = {avg_dice:.4f}")
    print(f"\tHausdorff Distance = {avg_hd:.4f}")
    print(f"\tVolumetric Difference = {avg_vd:.4f}")
# Out:
# Collecting monai==0.9.1
#   Downloading monai-0.9.1-202207251608-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from monai==0.9.1) (2.5.1+cu121)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from monai==0.9.1) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.7->monai==0.9.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->monai==0.9.1) (3.0.2)
# Downloading monai-0.9.1-202207251608-py3-none-any.whl (990 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 990.7/990.7 kB 13.1 MB/s eta 0:00:00
# Installing collected packages: monai
# Successfully installed monai-0.9.1
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (5.3.2)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.10/dist-packages (from nibabel) (6.4.5)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from nibabel) (1.26.4)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from nibabel) (4.12.2)
# Collecting SimpleITK
#   Downloading SimpleITK-2.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.9 kB)
# Downloading SimpleITK-2.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (52.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 MB 39.5 MB/s eta 0:00:00
# Installing collected packages: SimpleITK
# Successfully installed SimpleITK-2.4.0
# Mounted at /content/drive
# Sample image shape: (256, 128, 256, 1)
# Sample label shape: (256, 128, 256, 1)
# Sample image shape: (256, 128, 256, 1)
# Sample label shape: (256, 128, 256, 1)
# Loading dataset:   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/monai/data/utils.py:766: UserWarning: Modifying image pixdim from [0.8370536 1.5       0.8370536 0.       ] to [  0.8370536   1.5         0.8370536 213.4510119]
#   warnings.warn(f"Modifying image pixdim from {pixdim} to {norm}")
# /usr/local/lib/python3.10/dist-packages/monai/data/utils.py:766: UserWarning: Modifying image pixdim from [1.  1.5 1.  0. ] to [  1.           1.5          1.         255.00196078]
#   warnings.warn(f"Modifying image pixdim from {pixdim} to {norm}")
# Loading dataset:  30%|███       | 3/10 [00:00<00:02,  3.50it/s]/usr/local/lib/python3.10/dist-packages/monai/data/utils.py:766: UserWarning: Modifying image pixdim from [0.9375 1.5    0.9375 0.    ] to [  0.9375       1.5          0.9375     239.06459149]
#   warnings.warn(f"Modifying image pixdim from {pixdim} to {norm}")
# Loading dataset: 100%|██████████| 10/10 [00:02<00:00,  3.51it/s]
# Loading dataset: 100%|██████████| 5/5 [00:01<00:00,  4.09it/s]
# SwinUNETR model instantiated successfully!
# ----------
# Epoch 1/2000
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1512: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1512: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1512: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1512: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/monai/data/__init__.py:117: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   t = cls([], dtype=storage.dtype, device=storage.device)
# 1/10, train_loss: 0.8055
# 2/10, train_loss: 0.7625
# 3/10, train_loss: 0.7495
# 4/10, train_loss: 0.6764
# 5/10, train_loss: 0.6809
# 6/10, train_loss: 0.6615
# 7/10, train_loss: 0.7765
# 8/10, train_loss: 0.6154
# 9/10, train_loss: 0.8063
# 10/10, train_loss: 0.5544
# Epoch 1 average loss: 0.7089
# ----------
# Epoch 2/2000
# 1/10, train_loss: 0.7974
# 2/10, train_loss: 0.5136
# 3/10, train_loss: 0.8641
# 4/10, train_loss: 0.6691
# 5/10, train_loss: 0.4902
# 6/10, train_loss: 0.4826
# 7/10, train_loss: 0.6213
# 8/10, train_loss: 0.5456
# 9/10, train_loss: 0.5369
# 10/10, train_loss: 0.6074
# Epoch 2 average loss: 0.6128
# /usr/local/lib/python3.10/dist-packages/monai/metrics/utils.py:219: UserWarning: y_pred should be a binarized tensor.
#   warnings.warn(f"{name} should be a binarized tensor.")
# Streaming output truncated to the last 5000 lines.
# Current epoch: 1630 current mean dice: 0.9175 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1631/2000
# 1/10, train_loss: 0.0552
# 2/10, train_loss: 0.0495
# 3/10, train_loss: 0.0612
# 4/10, train_loss: 0.0952
# 5/10, train_loss: 0.2849
# 6/10, train_loss: 0.0568
# 7/10, train_loss: 0.1108
# 8/10, train_loss: 0.0691
# 9/10, train_loss: 0.3426
# 10/10, train_loss: 0.0856
# Epoch 1631 average loss: 0.1211
# ----------
# Epoch 1632/2000
# 1/10, train_loss: 0.0512
# 2/10, train_loss: 0.2730
# 3/10, train_loss: 0.0656
# 4/10, train_loss: 0.0720
# 5/10, train_loss: 0.0442
# 6/10, train_loss: 0.0612
# 7/10, train_loss: 0.0918
# 8/10, train_loss: 0.0662
# 9/10, train_loss: 0.0727
# 10/10, train_loss: 0.0860
# Epoch 1632 average loss: 0.0884
# Current epoch: 1632 current mean dice: 0.9214 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1633/2000
# 1/10, train_loss: 0.0581
# 2/10, train_loss: 0.0659
# 3/10, train_loss: 0.3072
# 4/10, train_loss: 0.0626
# 5/10, train_loss: 0.0512
# 6/10, train_loss: 0.0674
# 7/10, train_loss: 0.0716
# 8/10, train_loss: 0.0791
# 9/10, train_loss: 0.0782
# 10/10, train_loss: 0.0595
# Epoch 1633 average loss: 0.0901
# ----------
# Epoch 1634/2000
# 1/10, train_loss: 0.0561
# 2/10, train_loss: 0.0574
# 3/10, train_loss: 0.0842
# 4/10, train_loss: 0.0669
# 5/10, train_loss: 0.1267
# 6/10, train_loss: 0.0915
# 7/10, train_loss: 0.0957
# 8/10, train_loss: 0.0971
# 9/10, train_loss: 0.0496
# 10/10, train_loss: 0.0753
# Epoch 1634 average loss: 0.0800
# Current epoch: 1634 current mean dice: 0.9205 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1635/2000
# 1/10, train_loss: 0.0589
# 2/10, train_loss: 0.0847
# 3/10, train_loss: 0.0618
# 4/10, train_loss: 0.0979
# 5/10, train_loss: 0.0855
# 6/10, train_loss: 0.1286
# 7/10, train_loss: 0.0597
# 8/10, train_loss: 0.0802
# 9/10, train_loss: 0.1355
# 10/10, train_loss: 0.0863
# Epoch 1635 average loss: 0.0879
# ----------
# Epoch 1636/2000
# 1/10, train_loss: 0.0567
# 2/10, train_loss: 0.0827
# 3/10, train_loss: 0.0682
# 4/10, train_loss: 0.1689
# 5/10, train_loss: 0.0403
# 6/10, train_loss: 0.0539
# 7/10, train_loss: 0.0620
# 8/10, train_loss: 0.0657
# 9/10, train_loss: 0.0946
# 10/10, train_loss: 0.0744
# Epoch 1636 average loss: 0.0767
# Current epoch: 1636 current mean dice: 0.9190 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1637/2000
# 1/10, train_loss: 0.0416
# 2/10, train_loss: 0.0554
# 3/10, train_loss: 0.0664
# 4/10, train_loss: 0.1208
# 5/10, train_loss: 0.0954
# 6/10, train_loss: 0.1191
# 7/10, train_loss: 0.0555
# 8/10, train_loss: 0.0669
# 9/10, train_loss: 0.1267
# 10/10, train_loss: 0.0826
# Epoch 1637 average loss: 0.0830
# ----------
# Epoch 1638/2000
# 1/10, train_loss: 0.0636
# 2/10, train_loss: 0.0676
# 3/10, train_loss: 0.0665
# 4/10, train_loss: 0.0471
# 5/10, train_loss: 0.2819
# 6/10, train_loss: 0.0852
# 7/10, train_loss: 0.1403
# 8/10, train_loss: 0.0883
# 9/10, train_loss: 0.2304
# 10/10, train_loss: 0.0858
# Epoch 1638 average loss: 0.1157
# Current epoch: 1638 current mean dice: 0.9214 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1639/2000
# 1/10, train_loss: 0.0862
# 2/10, train_loss: 0.0488
# 3/10, train_loss: 0.0773
# 4/10, train_loss: 0.0479
# 5/10, train_loss: 0.0447
# 6/10, train_loss: 0.0876
# 7/10, train_loss: 0.0656
# 8/10, train_loss: 0.0482
# 9/10, train_loss: 0.0896
# 10/10, train_loss: 0.0690
# Epoch 1639 average loss: 0.0665
# ----------
# Epoch 1640/2000
# 1/10, train_loss: 0.0561
# 2/10, train_loss: 0.0611
# 3/10, train_loss: 0.2828
# 4/10, train_loss: 0.0631
# 5/10, train_loss: 0.2699
# 6/10, train_loss: 0.0745
# 7/10, train_loss: 0.0476
# 8/10, train_loss: 0.0761
# 9/10, train_loss: 0.2896
# 10/10, train_loss: 0.0329
# Epoch 1640 average loss: 0.1254
# Current epoch: 1640 current mean dice: 0.9222 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1641/2000
# 1/10, train_loss: 0.0838
# 2/10, train_loss: 0.0830
# 3/10, train_loss: 0.0602
# 4/10, train_loss: 0.0739
# 5/10, train_loss: 0.0542
# 6/10, train_loss: 0.0610
# 7/10, train_loss: 0.0818
# 8/10, train_loss: 0.0720
# 9/10, train_loss: 0.0521
# 10/10, train_loss: 0.0581
# Epoch 1641 average loss: 0.0680
# ----------
# Epoch 1642/2000
# 1/10, train_loss: 0.0818
# 2/10, train_loss: 0.0855
# 3/10, train_loss: 0.0732
# 4/10, train_loss: 0.0496
# 5/10, train_loss: 0.0827
# 6/10, train_loss: 0.0523
# 7/10, train_loss: 0.0563
# 8/10, train_loss: 0.0764
# 9/10, train_loss: 0.0917
# 10/10, train_loss: 0.0596
# Epoch 1642 average loss: 0.0709
# Current epoch: 1642 current mean dice: 0.9242 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1643/2000
# 1/10, train_loss: 0.0782
# 2/10, train_loss: 0.0567
# 3/10, train_loss: 0.0662
# 4/10, train_loss: 0.0619
# 5/10, train_loss: 0.0856
# 6/10, train_loss: 0.0663
# 7/10, train_loss: 0.0601
# 8/10, train_loss: 0.0758
# 9/10, train_loss: 0.0416
# 10/10, train_loss: 0.0748
# Epoch 1643 average loss: 0.0667
# ----------
# Epoch 1644/2000
# 1/10, train_loss: 0.0565
# 2/10, train_loss: 0.1283
# 3/10, train_loss: 0.0349
# 4/10, train_loss: 0.1354
# 5/10, train_loss: 0.0843
# 6/10, train_loss: 0.0597
# 7/10, train_loss: 0.0682
# 8/10, train_loss: 0.0646
# 9/10, train_loss: 0.0891
# 10/10, train_loss: 0.0887
# Epoch 1644 average loss: 0.0810
# Current epoch: 1644 current mean dice: 0.9247 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1645/2000
# 1/10, train_loss: 0.0758
# 2/10, train_loss: 0.0744
# 3/10, train_loss: 0.0681
# 4/10, train_loss: 0.0569
# 5/10, train_loss: 0.1041
# 6/10, train_loss: 0.1623
# 7/10, train_loss: 0.0744
# 8/10, train_loss: 0.0932
# 9/10, train_loss: 0.3056
# 10/10, train_loss: 0.0560
# Epoch 1645 average loss: 0.1071
# ----------
# Epoch 1646/2000
# 1/10, train_loss: 0.0589
# 2/10, train_loss: 0.0704
# 3/10, train_loss: 0.0901
# 4/10, train_loss: 0.0495
# 5/10, train_loss: 0.2771
# 6/10, train_loss: 0.0614
# 7/10, train_loss: 0.0668
# 8/10, train_loss: 0.0551
# 9/10, train_loss: 0.0614
# 10/10, train_loss: 0.1971
# Epoch 1646 average loss: 0.0988
# Current epoch: 1646 current mean dice: 0.9242 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1647/2000
# 1/10, train_loss: 0.2739
# 2/10, train_loss: 0.0885
# 3/10, train_loss: 0.0761
# 4/10, train_loss: 0.0891
# 5/10, train_loss: 0.0857
# 6/10, train_loss: 0.0439
# 7/10, train_loss: 0.0351
# 8/10, train_loss: 0.0743
# 9/10, train_loss: 0.0792
# 10/10, train_loss: 0.0753
# Epoch 1647 average loss: 0.0921
# ----------
# Epoch 1648/2000
# 1/10, train_loss: 0.0595
# 2/10, train_loss: 0.3108
# 3/10, train_loss: 0.0661
# 4/10, train_loss: 0.0451
# 5/10, train_loss: 0.0640
# 6/10, train_loss: 0.0510
# 7/10, train_loss: 0.0709
# 8/10, train_loss: 0.0542
# 9/10, train_loss: 0.0810
# 10/10, train_loss: 0.0566
# Epoch 1648 average loss: 0.0859
# Current epoch: 1648 current mean dice: 0.9223 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1649/2000
# 1/10, train_loss: 0.0806
# 2/10, train_loss: 0.0834
# 3/10, train_loss: 0.0544
# 4/10, train_loss: 0.0676
# 5/10, train_loss: 0.0690
# 6/10, train_loss: 0.2778
# 7/10, train_loss: 0.0444
# 8/10, train_loss: 0.0528
# 9/10, train_loss: 0.0589
# 10/10, train_loss: 0.0706
# Epoch 1649 average loss: 0.0860
# ----------
# Epoch 1650/2000
# 1/10, train_loss: 0.0902
# 2/10, train_loss: 0.1660
# 3/10, train_loss: 0.0863
# 4/10, train_loss: 0.0711
# 5/10, train_loss: 0.0542
# 6/10, train_loss: 0.0723
# 7/10, train_loss: 0.0694
# 8/10, train_loss: 0.0824
# 9/10, train_loss: 0.0618
# 10/10, train_loss: 0.0653
# Epoch 1650 average loss: 0.0819
# Current epoch: 1650 current mean dice: 0.9247 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1651/2000
# 1/10, train_loss: 0.0575
# 2/10, train_loss: 0.0501
# 3/10, train_loss: 0.0758
# 4/10, train_loss: 0.1739
# 5/10, train_loss: 0.0657
# 6/10, train_loss: 0.0753
# 7/10, train_loss: 0.0853
# 8/10, train_loss: 0.0673
# 9/10, train_loss: 0.0594
# 10/10, train_loss: 0.0483
# Epoch 1651 average loss: 0.0759
# ----------
# Epoch 1652/2000
# 1/10, train_loss: 0.1492
# 2/10, train_loss: 0.0508
# 3/10, train_loss: 0.0512
# 4/10, train_loss: 0.0871
# 5/10, train_loss: 0.0647
# 6/10, train_loss: 0.0693
# 7/10, train_loss: 0.0905
# 8/10, train_loss: 0.0559
# 9/10, train_loss: 0.1039
# 10/10, train_loss: 0.0773
# Epoch 1652 average loss: 0.0800
# Current epoch: 1652 current mean dice: 0.9220 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1653/2000
# 1/10, train_loss: 0.0482
# 2/10, train_loss: 0.0930
# 3/10, train_loss: 0.0730
# 4/10, train_loss: 0.0593
# 5/10, train_loss: 0.0606
# 6/10, train_loss: 0.2755
# 7/10, train_loss: 0.0488
# 8/10, train_loss: 0.0586
# 9/10, train_loss: 0.0644
# 10/10, train_loss: 0.3134
# Epoch 1653 average loss: 0.1095
# ----------
# Epoch 1654/2000
# 1/10, train_loss: 0.0635
# 2/10, train_loss: 0.0398
# 3/10, train_loss: 0.1379
# 4/10, train_loss: 0.1212
# 5/10, train_loss: 0.0618
# 6/10, train_loss: 0.0544
# 7/10, train_loss: 0.1324
# 8/10, train_loss: 0.0724
# 9/10, train_loss: 0.0438
# 10/10, train_loss: 0.0527
# Epoch 1654 average loss: 0.0780
# Current epoch: 1654 current mean dice: 0.9184 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1655/2000
# 1/10, train_loss: 0.0480
# 2/10, train_loss: 0.2742
# 3/10, train_loss: 0.0654
# 4/10, train_loss: 0.0718
# 5/10, train_loss: 0.0515
# 6/10, train_loss: 0.0833
# 7/10, train_loss: 0.0427
# 8/10, train_loss: 0.0883
# 9/10, train_loss: 0.1127
# 10/10, train_loss: 0.0639
# Epoch 1655 average loss: 0.0902
# ----------
# Epoch 1656/2000
# 1/10, train_loss: 0.3029
# 2/10, train_loss: 0.0769
# 3/10, train_loss: 0.0600
# 4/10, train_loss: 0.0872
# 5/10, train_loss: 0.0687
# 6/10, train_loss: 0.0670
# 7/10, train_loss: 0.0492
# 8/10, train_loss: 0.0494
# 9/10, train_loss: 0.0586
# 10/10, train_loss: 0.0565
# Epoch 1656 average loss: 0.0876
# Current epoch: 1656 current mean dice: 0.9186 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1657/2000
# 1/10, train_loss: 0.0328
# 2/10, train_loss: 0.0443
# 3/10, train_loss: 0.0948
# 4/10, train_loss: 0.0679
# 5/10, train_loss: 0.0421
# 6/10, train_loss: 0.0887
# 7/10, train_loss: 0.0732
# 8/10, train_loss: 0.0576
# 9/10, train_loss: 0.0586
# 10/10, train_loss: 0.0755
# Epoch 1657 average loss: 0.0635
# ----------
# Epoch 1658/2000
# 1/10, train_loss: 0.0660
# 2/10, train_loss: 0.1176
# 3/10, train_loss: 0.0387
# 4/10, train_loss: 0.0910
# 5/10, train_loss: 0.0884
# 6/10, train_loss: 0.0535
# 7/10, train_loss: 0.0629
# 8/10, train_loss: 0.1039
# 9/10, train_loss: 0.0491
# 10/10, train_loss: 0.0911
# Epoch 1658 average loss: 0.0762
# Current epoch: 1658 current mean dice: 0.9226 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1659/2000
# 1/10, train_loss: 0.0533
# 2/10, train_loss: 0.0632
# 3/10, train_loss: 0.0833
# 4/10, train_loss: 0.0425
# 5/10, train_loss: 0.0584
# 6/10, train_loss: 0.0420
# 7/10, train_loss: 0.0643
# 8/10, train_loss: 0.0582
# 9/10, train_loss: 0.0640
# 10/10, train_loss: 0.0546
# Epoch 1659 average loss: 0.0584
# ----------
# Epoch 1660/2000
# 1/10, train_loss: 0.0807
# 2/10, train_loss: 0.0812
# 3/10, train_loss: 0.1134
# 4/10, train_loss: 0.0564
# 5/10, train_loss: 0.0597
# 6/10, train_loss: 0.0655
# 7/10, train_loss: 0.0535
# 8/10, train_loss: 0.0627
# 9/10, train_loss: 0.0539
# 10/10, train_loss: 0.0685
# Epoch 1660 average loss: 0.0696
# Current epoch: 1660 current mean dice: 0.9227 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1661/2000
# 1/10, train_loss: 0.0568
# 2/10, train_loss: 0.1766
# 3/10, train_loss: 0.1050
# 4/10, train_loss: 0.0489
# 5/10, train_loss: 0.0727
# 6/10, train_loss: 0.0537
# 7/10, train_loss: 0.0785
# 8/10, train_loss: 0.0735
# 9/10, train_loss: 0.1037
# 10/10, train_loss: 0.0432
# Epoch 1661 average loss: 0.0813
# ----------
# Epoch 1662/2000
# 1/10, train_loss: 0.0355
# 2/10, train_loss: 0.0868
# 3/10, train_loss: 0.0420
# 4/10, train_loss: 0.0561
# 5/10, train_loss: 0.0617
# 6/10, train_loss: 0.0707
# 7/10, train_loss: 0.0593
# 8/10, train_loss: 0.0437
# 9/10, train_loss: 0.0665
# 10/10, train_loss: 0.0425
# Epoch 1662 average loss: 0.0565
# Current epoch: 1662 current mean dice: 0.9207 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1663/2000
# 1/10, train_loss: 0.0500
# 2/10, train_loss: 0.0775
# 3/10, train_loss: 0.0564
# 4/10, train_loss: 0.0717
# 5/10, train_loss: 0.0589
# 6/10, train_loss: 0.0913
# 7/10, train_loss: 0.0594
# 8/10, train_loss: 0.0547
# 9/10, train_loss: 0.0573
# 10/10, train_loss: 0.3125
# Epoch 1663 average loss: 0.0890
# ----------
# Epoch 1664/2000
# 1/10, train_loss: 0.0941
# 2/10, train_loss: 0.0690
# 3/10, train_loss: 0.0683
# 4/10, train_loss: 0.0585
# 5/10, train_loss: 0.0813
# 6/10, train_loss: 0.0491
# 7/10, train_loss: 0.0456
# 8/10, train_loss: 0.0480
# 9/10, train_loss: 0.0577
# 10/10, train_loss: 0.1020
# Epoch 1664 average loss: 0.0674
# Current epoch: 1664 current mean dice: 0.9216 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1665/2000
# 1/10, train_loss: 0.0672
# 2/10, train_loss: 0.0560
# 3/10, train_loss: 0.0496
# 4/10, train_loss: 0.0858
# 5/10, train_loss: 0.0504
# 6/10, train_loss: 0.0799
# 7/10, train_loss: 0.0520
# 8/10, train_loss: 0.0480
# 9/10, train_loss: 0.0538
# 10/10, train_loss: 0.0607
# Epoch 1665 average loss: 0.0603
# ----------
# Epoch 1666/2000
# 1/10, train_loss: 0.1118
# 2/10, train_loss: 0.2754
# 3/10, train_loss: 0.0452
# 4/10, train_loss: 0.0436
# 5/10, train_loss: 0.2871
# 6/10, train_loss: 0.0896
# 7/10, train_loss: 0.0504
# 8/10, train_loss: 0.0759
# 9/10, train_loss: 0.0543
# 10/10, train_loss: 0.0517
# Epoch 1666 average loss: 0.1085
# Current epoch: 1666 current mean dice: 0.9179 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1667/2000
# 1/10, train_loss: 0.1072
# 2/10, train_loss: 0.0801
# 3/10, train_loss: 0.0542
# 4/10, train_loss: 0.0728
# 5/10, train_loss: 0.0843
# 6/10, train_loss: 0.0733
# 7/10, train_loss: 0.1071
# 8/10, train_loss: 0.2899
# 9/10, train_loss: 0.0363
# 10/10, train_loss: 0.0442
# Epoch 1667 average loss: 0.0949
# ----------
# Epoch 1668/2000
# 1/10, train_loss: 0.0513
# 2/10, train_loss: 0.0817
# 3/10, train_loss: 0.0920
# 4/10, train_loss: 0.1063
# 5/10, train_loss: 0.0920
# 6/10, train_loss: 0.0605
# 7/10, train_loss: 0.0566
# 8/10, train_loss: 0.0565
# 9/10, train_loss: 0.0620
# 10/10, train_loss: 0.0428
# Epoch 1668 average loss: 0.0702
# Current epoch: 1668 current mean dice: 0.9197 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1669/2000
# 1/10, train_loss: 0.0572
# 2/10, train_loss: 0.0573
# 3/10, train_loss: 0.0432
# 4/10, train_loss: 0.0675
# 5/10, train_loss: 0.0664
# 6/10, train_loss: 0.1054
# 7/10, train_loss: 0.0648
# 8/10, train_loss: 0.0436
# 9/10, train_loss: 0.0953
# 10/10, train_loss: 0.0747
# Epoch 1669 average loss: 0.0675
# ----------
# Epoch 1670/2000
# 1/10, train_loss: 0.0705
# 2/10, train_loss: 0.0588
# 3/10, train_loss: 0.0601
# 4/10, train_loss: 0.0752
# 5/10, train_loss: 0.0583
# 6/10, train_loss: 0.1175
# 7/10, train_loss: 0.0593
# 8/10, train_loss: 0.0371
# 9/10, train_loss: 0.1093
# 10/10, train_loss: 0.0726
# Epoch 1670 average loss: 0.0719
# Current epoch: 1670 current mean dice: 0.9238 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1671/2000
# 1/10, train_loss: 0.0460
# 2/10, train_loss: 0.0416
# 3/10, train_loss: 0.0668
# 4/10, train_loss: 0.0508
# 5/10, train_loss: 0.0662
# 6/10, train_loss: 0.0647
# 7/10, train_loss: 0.0601
# 8/10, train_loss: 0.0819
# 9/10, train_loss: 0.0625
# 10/10, train_loss: 0.0684
# Epoch 1671 average loss: 0.0609
# ----------
# Epoch 1672/2000
# 1/10, train_loss: 0.1619
# 2/10, train_loss: 0.0486
# 3/10, train_loss: 0.1982
# 4/10, train_loss: 0.0539
# 5/10, train_loss: 0.0744
# 6/10, train_loss: 0.1426
# 7/10, train_loss: 0.2826
# 8/10, train_loss: 0.0576
# 9/10, train_loss: 0.0916
# 10/10, train_loss: 0.0685
# Epoch 1672 average loss: 0.1180
# Current epoch: 1672 current mean dice: 0.9191 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1673/2000
# 1/10, train_loss: 0.0544
# 2/10, train_loss: 0.0593
# 3/10, train_loss: 0.0494
# 4/10, train_loss: 0.0612
# 5/10, train_loss: 0.2361
# 6/10, train_loss: 0.0581
# 7/10, train_loss: 0.0702
# 8/10, train_loss: 0.0534
# 9/10, train_loss: 0.1050
# 10/10, train_loss: 0.0676
# Epoch 1673 average loss: 0.0815
# ----------
# Epoch 1674/2000
# 1/10, train_loss: 0.0930
# 2/10, train_loss: 0.0814
# 3/10, train_loss: 0.1230
# 4/10, train_loss: 0.0748
# 5/10, train_loss: 0.0465
# 6/10, train_loss: 0.1424
# 7/10, train_loss: 0.0977
# 8/10, train_loss: 0.1335
# 9/10, train_loss: 0.0562
# 10/10, train_loss: 0.0451
# Epoch 1674 average loss: 0.0894
# Current epoch: 1674 current mean dice: 0.9087 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1675/2000
# 1/10, train_loss: 0.1069
# 2/10, train_loss: 0.0491
# 3/10, train_loss: 0.0570
# 4/10, train_loss: 0.0887
# 5/10, train_loss: 0.0914
# 6/10, train_loss: 0.0844
# 7/10, train_loss: 0.0607
# 8/10, train_loss: 0.1168
# 9/10, train_loss: 0.0667
# 10/10, train_loss: 0.0481
# Epoch 1675 average loss: 0.0770
# ----------
# Epoch 1676/2000
# 1/10, train_loss: 0.0605
# 2/10, train_loss: 0.0549
# 3/10, train_loss: 0.0675
# 4/10, train_loss: 0.0873
# 5/10, train_loss: 0.0740
# 6/10, train_loss: 0.0858
# 7/10, train_loss: 0.0622
# 8/10, train_loss: 0.0749
# 9/10, train_loss: 0.1556
# 10/10, train_loss: 0.0455
# Epoch 1676 average loss: 0.0768
# Current epoch: 1676 current mean dice: 0.9193 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1677/2000
# 1/10, train_loss: 0.0968
# 2/10, train_loss: 0.0763
# 3/10, train_loss: 0.0941
# 4/10, train_loss: 0.0928
# 5/10, train_loss: 0.0997
# 6/10, train_loss: 0.0703
# 7/10, train_loss: 0.0839
# 8/10, train_loss: 0.0862
# 9/10, train_loss: 0.2679
# 10/10, train_loss: 0.0928
# Epoch 1677 average loss: 0.1061
# ----------
# Epoch 1678/2000
# 1/10, train_loss: 0.0436
# 2/10, train_loss: 0.3382
# 3/10, train_loss: 0.0933
# 4/10, train_loss: 0.0901
# 5/10, train_loss: 0.0504
# 6/10, train_loss: 0.1174
# 7/10, train_loss: 0.1138
# 8/10, train_loss: 0.0677
# 9/10, train_loss: 0.0754
# 10/10, train_loss: 0.0894
# Epoch 1678 average loss: 0.1079
# Current epoch: 1678 current mean dice: 0.9201 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1679/2000
# 1/10, train_loss: 0.0722
# 2/10, train_loss: 0.0540
# 3/10, train_loss: 0.0646
# 4/10, train_loss: 0.0511
# 5/10, train_loss: 0.0528
# 6/10, train_loss: 0.0693
# 7/10, train_loss: 0.0699
# 8/10, train_loss: 0.0345
# 9/10, train_loss: 0.0573
# 10/10, train_loss: 0.0629
# Epoch 1679 average loss: 0.0589
# ----------
# Epoch 1680/2000
# 1/10, train_loss: 0.2830
# 2/10, train_loss: 0.0659
# 3/10, train_loss: 0.0360
# 4/10, train_loss: 0.0607
# 5/10, train_loss: 0.0656
# 6/10, train_loss: 0.0361
# 7/10, train_loss: 0.0694
# 8/10, train_loss: 0.0759
# 9/10, train_loss: 0.0550
# 10/10, train_loss: 0.0564
# Epoch 1680 average loss: 0.0804
# Current epoch: 1680 current mean dice: 0.9219 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1681/2000
# 1/10, train_loss: 0.0408
# 2/10, train_loss: 0.0912
# 3/10, train_loss: 0.0711
# 4/10, train_loss: 0.0586
# 5/10, train_loss: 0.0722
# 6/10, train_loss: 0.0658
# 7/10, train_loss: 0.1024
# 8/10, train_loss: 0.0425
# 9/10, train_loss: 0.0579
# 10/10, train_loss: 0.0617
# Epoch 1681 average loss: 0.0664
# ----------
# Epoch 1682/2000
# 1/10, train_loss: 0.0877
# 2/10, train_loss: 0.0482
# 3/10, train_loss: 0.0954
# 4/10, train_loss: 0.0877
# 5/10, train_loss: 0.0370
# 6/10, train_loss: 0.0475
# 7/10, train_loss: 0.1368
# 8/10, train_loss: 0.0511
# 9/10, train_loss: 0.0709
# 10/10, train_loss: 0.0619
# Epoch 1682 average loss: 0.0724
# Current epoch: 1682 current mean dice: 0.9269 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1683/2000
# 1/10, train_loss: 0.0584
# 2/10, train_loss: 0.0480
# 3/10, train_loss: 0.0606
# 4/10, train_loss: 0.0666
# 5/10, train_loss: 0.0544
# 6/10, train_loss: 0.0633
# 7/10, train_loss: 0.0685
# 8/10, train_loss: 0.0571
# 9/10, train_loss: 0.0677
# 10/10, train_loss: 0.0656
# Epoch 1683 average loss: 0.0610
# ----------
# Epoch 1684/2000
# 1/10, train_loss: 0.0654
# 2/10, train_loss: 0.0681
# 3/10, train_loss: 0.0505
# 4/10, train_loss: 0.0624
# 5/10, train_loss: 0.0581
# 6/10, train_loss: 0.0682
# 7/10, train_loss: 0.0803
# 8/10, train_loss: 0.0588
# 9/10, train_loss: 0.0375
# 10/10, train_loss: 0.0667
# Epoch 1684 average loss: 0.0616
# Current epoch: 1684 current mean dice: 0.9266 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1685/2000
# 1/10, train_loss: 0.0595
# 2/10, train_loss: 0.0579
# 3/10, train_loss: 0.2859
# 4/10, train_loss: 0.0563
# 5/10, train_loss: 0.0598
# 6/10, train_loss: 0.2752
# 7/10, train_loss: 0.0578
# 8/10, train_loss: 0.0787
# 9/10, train_loss: 0.1027
# 10/10, train_loss: 0.0496
# Epoch 1685 average loss: 0.1083
# ----------
# Epoch 1686/2000
# 1/10, train_loss: 0.2762
# 2/10, train_loss: 0.0524
# 3/10, train_loss: 0.0812
# 4/10, train_loss: 0.0612
# 5/10, train_loss: 0.0593
# 6/10, train_loss: 0.0795
# 7/10, train_loss: 0.0828
# 8/10, train_loss: 0.0740
# 9/10, train_loss: 0.0712
# 10/10, train_loss: 0.0843
# Epoch 1686 average loss: 0.0922
# Current epoch: 1686 current mean dice: 0.9247 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1687/2000
# 1/10, train_loss: 0.2339
# 2/10, train_loss: 0.0968
# 3/10, train_loss: 0.1012
# 4/10, train_loss: 0.0645
# 5/10, train_loss: 0.0649
# 6/10, train_loss: 0.0505
# 7/10, train_loss: 0.0620
# 8/10, train_loss: 0.0856
# 9/10, train_loss: 0.0844
# 10/10, train_loss: 0.0870
# Epoch 1687 average loss: 0.0931
# ----------
# Epoch 1688/2000
# 1/10, train_loss: 0.0598
# 2/10, train_loss: 0.0671
# 3/10, train_loss: 0.2837
# 4/10, train_loss: 0.0703
# 5/10, train_loss: 0.0725
# 6/10, train_loss: 0.0657
# 7/10, train_loss: 0.1029
# 8/10, train_loss: 0.0579
# 9/10, train_loss: 0.0503
# 10/10, train_loss: 0.0722
# Epoch 1688 average loss: 0.0902
# Current epoch: 1688 current mean dice: 0.9228 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1689/2000
# 1/10, train_loss: 0.3054
# 2/10, train_loss: 0.0936
# 3/10, train_loss: 0.2719
# 4/10, train_loss: 0.0549
# 5/10, train_loss: 0.0519
# 6/10, train_loss: 0.0536
# 7/10, train_loss: 0.0527
# 8/10, train_loss: 0.0580
# 9/10, train_loss: 0.0783
# 10/10, train_loss: 0.0904
# Epoch 1689 average loss: 0.1111
# ----------
# Epoch 1690/2000
# 1/10, train_loss: 0.0430
# 2/10, train_loss: 0.0731
# 3/10, train_loss: 0.0611
# 4/10, train_loss: 0.0630
# 5/10, train_loss: 0.2792
# 6/10, train_loss: 0.0631
# 7/10, train_loss: 0.0938
# 8/10, train_loss: 0.1758
# 9/10, train_loss: 0.0567
# 10/10, train_loss: 0.0525
# Epoch 1690 average loss: 0.0961
# Current epoch: 1690 current mean dice: 0.9232 best mean dice: 0.9269 at epoch 1436
# ----------
# Epoch 1691/2000
# 1/10, train_loss: 0.2740
# 2/10, train_loss: 0.0825
# 3/10, train_loss: 0.0732
# 4/10, train_loss: 0.0965
# 5/10, train_loss: 0.0403
# 6/10, train_loss: 0.0761
# 7/10, train_loss: 0.0874
# 8/10, train_loss: 0.0704
# 9/10, train_loss: 0.0683
# 10/10, train_loss: 0.0421
# Epoch 1691 average loss: 0.0911
# ----------
# Epoch 1692/2000
# 1/10, train_loss: 0.0579
# 2/10, train_loss: 0.0592
# 3/10, train_loss: 0.0629
# 4/10, train_loss: 0.0578
# 5/10, train_loss: 0.0524
# 6/10, train_loss: 0.0497
# 7/10, train_loss: 0.0707
# 8/10, train_loss: 0.0874
# 9/10, train_loss: 0.0469
# 10/10, train_loss: 0.0592
# Epoch 1692 average loss: 0.0604
# Saved new best metric model
# Current epoch: 1692 current mean dice: 0.9271 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1693/2000
# 1/10, train_loss: 0.0571
# 2/10, train_loss: 0.0624
# 3/10, train_loss: 0.0369
# 4/10, train_loss: 0.2755
# 5/10, train_loss: 0.1295
# 6/10, train_loss: 0.0730
# 7/10, train_loss: 0.0696
# 8/10, train_loss: 0.0716
# 9/10, train_loss: 0.1509
# 10/10, train_loss: 0.0644
# Epoch 1693 average loss: 0.0991
# ----------
# Epoch 1694/2000
# 1/10, train_loss: 0.2834
# 2/10, train_loss: 0.0593
# 3/10, train_loss: 0.0614
# 4/10, train_loss: 0.0586
# 5/10, train_loss: 0.0690
# 6/10, train_loss: 0.0655
# 7/10, train_loss: 0.0837
# 8/10, train_loss: 0.0470
# 9/10, train_loss: 0.0634
# 10/10, train_loss: 0.1557
# Epoch 1694 average loss: 0.0947
# Current epoch: 1694 current mean dice: 0.9270 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1695/2000
# 1/10, train_loss: 0.0752
# 2/10, train_loss: 0.2340
# 3/10, train_loss: 0.0508
# 4/10, train_loss: 0.0562
# 5/10, train_loss: 0.0659
# 6/10, train_loss: 0.0793
# 7/10, train_loss: 0.0813
# 8/10, train_loss: 0.0468
# 9/10, train_loss: 0.0454
# 10/10, train_loss: 0.0428
# Epoch 1695 average loss: 0.0778
# ----------
# Epoch 1696/2000
# 1/10, train_loss: 0.0666
# 2/10, train_loss: 0.0420
# 3/10, train_loss: 0.0691
# 4/10, train_loss: 0.0410
# 5/10, train_loss: 0.0573
# 6/10, train_loss: 0.0697
# 7/10, train_loss: 0.0855
# 8/10, train_loss: 0.0686
# 9/10, train_loss: 0.0584
# 10/10, train_loss: 0.0597
# Epoch 1696 average loss: 0.0618
# Current epoch: 1696 current mean dice: 0.9229 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1697/2000
# 1/10, train_loss: 0.0588
# 2/10, train_loss: 0.0569
# 3/10, train_loss: 0.0671
# 4/10, train_loss: 0.0532
# 5/10, train_loss: 0.0571
# 6/10, train_loss: 0.0580
# 7/10, train_loss: 0.0601
# 8/10, train_loss: 0.0685
# 9/10, train_loss: 0.0668
# 10/10, train_loss: 0.0541
# Epoch 1697 average loss: 0.0601
# ----------
# Epoch 1698/2000
# 1/10, train_loss: 0.0534
# 2/10, train_loss: 0.0834
# 3/10, train_loss: 0.0709
# 4/10, train_loss: 0.0606
# 5/10, train_loss: 0.1267
# 6/10, train_loss: 0.0743
# 7/10, train_loss: 0.0695
# 8/10, train_loss: 0.0945
# 9/10, train_loss: 0.0564
# 10/10, train_loss: 0.0979
# Epoch 1698 average loss: 0.0788
# Current epoch: 1698 current mean dice: 0.9225 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1699/2000
# 1/10, train_loss: 0.0909
# 2/10, train_loss: 0.0474
# 3/10, train_loss: 0.0928
# 4/10, train_loss: 0.0475
# 5/10, train_loss: 0.0553
# 6/10, train_loss: 0.0875
# 7/10, train_loss: 0.0732
# 8/10, train_loss: 0.0322
# 9/10, train_loss: 0.0785
# 10/10, train_loss: 0.0693
# Epoch 1699 average loss: 0.0674
# ----------
# Epoch 1700/2000
# 1/10, train_loss: 0.1213
# 2/10, train_loss: 0.0515
# 3/10, train_loss: 0.0773
# 4/10, train_loss: 0.0910
# 5/10, train_loss: 0.0779
# 6/10, train_loss: 0.0761
# 7/10, train_loss: 0.0562
# 8/10, train_loss: 0.0758
# 9/10, train_loss: 0.0680
# 10/10, train_loss: 0.0588
# Epoch 1700 average loss: 0.0754
# Current epoch: 1700 current mean dice: 0.9252 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1701/2000
# 1/10, train_loss: 0.0547
# 2/10, train_loss: 0.0808
# 3/10, train_loss: 0.0704
# 4/10, train_loss: 0.0784
# 5/10, train_loss: 0.0588
# 6/10, train_loss: 0.0769
# 7/10, train_loss: 0.0492
# 8/10, train_loss: 0.1372
# 9/10, train_loss: 0.0596
# 10/10, train_loss: 0.0460
# Epoch 1701 average loss: 0.0712
# ----------
# Epoch 1702/2000
# 1/10, train_loss: 0.0707
# 2/10, train_loss: 0.0385
# 3/10, train_loss: 0.0571
# 4/10, train_loss: 0.0532
# 5/10, train_loss: 0.0811
# 6/10, train_loss: 0.0642
# 7/10, train_loss: 0.0554
# 8/10, train_loss: 0.0841
# 9/10, train_loss: 0.0916
# 10/10, train_loss: 0.0676
# Epoch 1702 average loss: 0.0664
# Current epoch: 1702 current mean dice: 0.9235 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1703/2000
# 1/10, train_loss: 0.1066
# 2/10, train_loss: 0.0420
# 3/10, train_loss: 0.0588
# 4/10, train_loss: 0.0637
# 5/10, train_loss: 0.0608
# 6/10, train_loss: 0.0809
# 7/10, train_loss: 0.0942
# 8/10, train_loss: 0.0543
# 9/10, train_loss: 0.0873
# 10/10, train_loss: 0.0674
# Epoch 1703 average loss: 0.0716
# ----------
# Epoch 1704/2000
# 1/10, train_loss: 0.1142
# 2/10, train_loss: 0.0863
# 3/10, train_loss: 0.0452
# 4/10, train_loss: 0.0646
# 5/10, train_loss: 0.0453
# 6/10, train_loss: 0.0789
# 7/10, train_loss: 0.0600
# 8/10, train_loss: 0.0491
# 9/10, train_loss: 0.0679
# 10/10, train_loss: 0.0680
# Epoch 1704 average loss: 0.0679
# Current epoch: 1704 current mean dice: 0.9210 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1705/2000
# 1/10, train_loss: 0.0442
# 2/10, train_loss: 0.0336
# 3/10, train_loss: 0.0726
# 4/10, train_loss: 0.0785
# 5/10, train_loss: 0.0526
# 6/10, train_loss: 0.0467
# 7/10, train_loss: 0.0571
# 8/10, train_loss: 0.0791
# 9/10, train_loss: 0.0401
# 10/10, train_loss: 0.0583
# Epoch 1705 average loss: 0.0563
# ----------
# Epoch 1706/2000
# 1/10, train_loss: 0.0761
# 2/10, train_loss: 0.0731
# 3/10, train_loss: 0.0661
# 4/10, train_loss: 0.0619
# 5/10, train_loss: 0.0540
# 6/10, train_loss: 0.0603
# 7/10, train_loss: 0.1018
# 8/10, train_loss: 0.0735
# 9/10, train_loss: 0.0741
# 10/10, train_loss: 0.0687
# Epoch 1706 average loss: 0.0710
# Current epoch: 1706 current mean dice: 0.9238 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1707/2000
# 1/10, train_loss: 0.0616
# 2/10, train_loss: 0.0666
# 3/10, train_loss: 0.0562
# 4/10, train_loss: 0.0547
# 5/10, train_loss: 0.0616
# 6/10, train_loss: 0.0576
# 7/10, train_loss: 0.0562
# 8/10, train_loss: 0.0448
# 9/10, train_loss: 0.0642
# 10/10, train_loss: 0.0609
# Epoch 1707 average loss: 0.0584
# ----------
# Epoch 1708/2000
# 1/10, train_loss: 0.0603
# 2/10, train_loss: 0.0611
# 3/10, train_loss: 0.0817
# 4/10, train_loss: 0.0693
# 5/10, train_loss: 0.0912
# 6/10, train_loss: 0.0505
# 7/10, train_loss: 0.0536
# 8/10, train_loss: 0.0539
# 9/10, train_loss: 0.1221
# 10/10, train_loss: 0.0620
# Epoch 1708 average loss: 0.0706
# Current epoch: 1708 current mean dice: 0.9238 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1709/2000
# 1/10, train_loss: 0.0634
# 2/10, train_loss: 0.0470
# 3/10, train_loss: 0.0497
# 4/10, train_loss: 0.0567
# 5/10, train_loss: 0.1451
# 6/10, train_loss: 0.3044
# 7/10, train_loss: 0.0694
# 8/10, train_loss: 0.0674
# 9/10, train_loss: 0.0354
# 10/10, train_loss: 0.0574
# Epoch 1709 average loss: 0.0896
# ----------
# Epoch 1710/2000
# 1/10, train_loss: 0.0609
# 2/10, train_loss: 0.1366
# 3/10, train_loss: 0.0816
# 4/10, train_loss: 0.0420
# 5/10, train_loss: 0.0683
# 6/10, train_loss: 0.1012
# 7/10, train_loss: 0.0554
# 8/10, train_loss: 0.0769
# 9/10, train_loss: 0.0602
# 10/10, train_loss: 0.0479
# Epoch 1710 average loss: 0.0731
# Current epoch: 1710 current mean dice: 0.9248 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1711/2000
# 1/10, train_loss: 0.0683
# 2/10, train_loss: 0.0548
# 3/10, train_loss: 0.0715
# 4/10, train_loss: 0.0758
# 5/10, train_loss: 0.0880
# 6/10, train_loss: 0.0633
# 7/10, train_loss: 0.0713
# 8/10, train_loss: 0.0853
# 9/10, train_loss: 0.0644
# 10/10, train_loss: 0.0955
# Epoch 1711 average loss: 0.0738
# ----------
# Epoch 1712/2000
# 1/10, train_loss: 0.0854
# 2/10, train_loss: 0.0525
# 3/10, train_loss: 0.0615
# 4/10, train_loss: 0.0669
# 5/10, train_loss: 0.1218
# 6/10, train_loss: 0.0590
# 7/10, train_loss: 0.1534
# 8/10, train_loss: 0.0473
# 9/10, train_loss: 0.0613
# 10/10, train_loss: 0.0836
# Epoch 1712 average loss: 0.0793
# Current epoch: 1712 current mean dice: 0.9226 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1713/2000
# 1/10, train_loss: 0.2817
# 2/10, train_loss: 0.0792
# 3/10, train_loss: 0.0370
# 4/10, train_loss: 0.1050
# 5/10, train_loss: 0.0564
# 6/10, train_loss: 0.1695
# 7/10, train_loss: 0.0512
# 8/10, train_loss: 0.0559
# 9/10, train_loss: 0.0574
# 10/10, train_loss: 0.0354
# Epoch 1713 average loss: 0.0929
# ----------
# Epoch 1714/2000
# 1/10, train_loss: 0.0758
# 2/10, train_loss: 0.0620
# 3/10, train_loss: 0.0661
# 4/10, train_loss: 0.0529
# 5/10, train_loss: 0.0913
# 6/10, train_loss: 0.0861
# 7/10, train_loss: 0.0614
# 8/10, train_loss: 0.2856
# 9/10, train_loss: 0.0470
# 10/10, train_loss: 0.0678
# Epoch 1714 average loss: 0.0896
# Current epoch: 1714 current mean dice: 0.9226 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1715/2000
# 1/10, train_loss: 0.0539
# 2/10, train_loss: 0.0752
# 3/10, train_loss: 0.1000
# 4/10, train_loss: 0.0680
# 5/10, train_loss: 0.0592
# 6/10, train_loss: 0.0624
# 7/10, train_loss: 0.0719
# 8/10, train_loss: 0.0685
# 9/10, train_loss: 0.0622
# 10/10, train_loss: 0.0732
# Epoch 1715 average loss: 0.0695
# ----------
# Epoch 1716/2000
# 1/10, train_loss: 0.0578
# 2/10, train_loss: 0.0579
# 3/10, train_loss: 0.2839
# 4/10, train_loss: 0.0383
# 5/10, train_loss: 0.0590
# 6/10, train_loss: 0.0654
# 7/10, train_loss: 0.0510
# 8/10, train_loss: 0.0571
# 9/10, train_loss: 0.0515
# 10/10, train_loss: 0.0799
# Epoch 1716 average loss: 0.0802
# Current epoch: 1716 current mean dice: 0.9213 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1717/2000
# 1/10, train_loss: 0.1115
# 2/10, train_loss: 0.2739
# 3/10, train_loss: 0.0770
# 4/10, train_loss: 0.0487
# 5/10, train_loss: 0.0687
# 6/10, train_loss: 0.0978
# 7/10, train_loss: 0.0806
# 8/10, train_loss: 0.0735
# 9/10, train_loss: 0.0663
# 10/10, train_loss: 0.0703
# Epoch 1717 average loss: 0.0968
# ----------
# Epoch 1718/2000
# 1/10, train_loss: 0.0443
# 2/10, train_loss: 0.0634
# 3/10, train_loss: 0.0803
# 4/10, train_loss: 0.0602
# 5/10, train_loss: 0.0448
# 6/10, train_loss: 0.0547
# 7/10, train_loss: 0.0528
# 8/10, train_loss: 0.0786
# 9/10, train_loss: 0.0659
# 10/10, train_loss: 0.0593
# Epoch 1718 average loss: 0.0604
# Current epoch: 1718 current mean dice: 0.9224 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1719/2000
# 1/10, train_loss: 0.0493
# 2/10, train_loss: 0.1045
# 3/10, train_loss: 0.2757
# 4/10, train_loss: 0.0769
# 5/10, train_loss: 0.0469
# 6/10, train_loss: 0.0745
# 7/10, train_loss: 0.0711
# 8/10, train_loss: 0.0850
# 9/10, train_loss: 0.2714
# 10/10, train_loss: 0.1056
# Epoch 1719 average loss: 0.1161
# ----------
# Epoch 1720/2000
# 1/10, train_loss: 0.0591
# 2/10, train_loss: 0.0437
# 3/10, train_loss: 0.0500
# 4/10, train_loss: 0.0460
# 5/10, train_loss: 0.0531
# 6/10, train_loss: 0.0459
# 7/10, train_loss: 0.0370
# 8/10, train_loss: 0.0814
# 9/10, train_loss: 0.0546
# 10/10, train_loss: 0.0333
# Epoch 1720 average loss: 0.0504
# Current epoch: 1720 current mean dice: 0.9212 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1721/2000
# 1/10, train_loss: 0.0537
# 2/10, train_loss: 0.0526
# 3/10, train_loss: 0.0552
# 4/10, train_loss: 0.0370
# 5/10, train_loss: 0.0624
# 6/10, train_loss: 0.0626
# 7/10, train_loss: 0.0422
# 8/10, train_loss: 0.0718
# 9/10, train_loss: 0.1298
# 10/10, train_loss: 0.0611
# Epoch 1721 average loss: 0.0628
# ----------
# Epoch 1722/2000
# 1/10, train_loss: 0.0389
# 2/10, train_loss: 0.0498
# 3/10, train_loss: 0.0425
# 4/10, train_loss: 0.1436
# 5/10, train_loss: 0.0550
# 6/10, train_loss: 0.0651
# 7/10, train_loss: 0.0600
# 8/10, train_loss: 0.0700
# 9/10, train_loss: 0.1091
# 10/10, train_loss: 0.0647
# Epoch 1722 average loss: 0.0699
# Current epoch: 1722 current mean dice: 0.9191 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1723/2000
# 1/10, train_loss: 0.0900
# 2/10, train_loss: 0.0812
# 3/10, train_loss: 0.0906
# 4/10, train_loss: 0.1074
# 5/10, train_loss: 0.0675
# 6/10, train_loss: 0.0840
# 7/10, train_loss: 0.0809
# 8/10, train_loss: 0.0505
# 9/10, train_loss: 0.0700
# 10/10, train_loss: 0.0931
# Epoch 1723 average loss: 0.0815
# ----------
# Epoch 1724/2000
# 1/10, train_loss: 0.0548
# 2/10, train_loss: 0.0865
# 3/10, train_loss: 0.0645
# 4/10, train_loss: 0.2771
# 5/10, train_loss: 0.0701
# 6/10, train_loss: 0.0902
# 7/10, train_loss: 0.2794
# 8/10, train_loss: 0.0641
# 9/10, train_loss: 0.0859
# 10/10, train_loss: 0.0676
# Epoch 1724 average loss: 0.1140
# Current epoch: 1724 current mean dice: 0.9196 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1725/2000
# 1/10, train_loss: 0.0835
# 2/10, train_loss: 0.0645
# 3/10, train_loss: 0.0588
# 4/10, train_loss: 0.0616
# 5/10, train_loss: 0.0828
# 6/10, train_loss: 0.0397
# 7/10, train_loss: 0.0719
# 8/10, train_loss: 0.0742
# 9/10, train_loss: 0.0589
# 10/10, train_loss: 0.0733
# Epoch 1725 average loss: 0.0669
# ----------
# Epoch 1726/2000
# 1/10, train_loss: 0.1036
# 2/10, train_loss: 0.0706
# 3/10, train_loss: 0.0733
# 4/10, train_loss: 0.0579
# 5/10, train_loss: 0.0723
# 6/10, train_loss: 0.1088
# 7/10, train_loss: 0.0779
# 8/10, train_loss: 0.0546
# 9/10, train_loss: 0.0685
# 10/10, train_loss: 0.0519
# Epoch 1726 average loss: 0.0739
# Current epoch: 1726 current mean dice: 0.9212 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1727/2000
# 1/10, train_loss: 0.2807
# 2/10, train_loss: 0.0416
# 3/10, train_loss: 0.0563
# 4/10, train_loss: 0.0773
# 5/10, train_loss: 0.0538
# 6/10, train_loss: 0.1132
# 7/10, train_loss: 0.0860
# 8/10, train_loss: 0.0672
# 9/10, train_loss: 0.0586
# 10/10, train_loss: 0.2727
# Epoch 1727 average loss: 0.1107
# ----------
# Epoch 1728/2000
# 1/10, train_loss: 0.0975
# 2/10, train_loss: 0.0552
# 3/10, train_loss: 0.0596
# 4/10, train_loss: 0.0593
# 5/10, train_loss: 0.0423
# 6/10, train_loss: 0.0797
# 7/10, train_loss: 0.0680
# 8/10, train_loss: 0.0804
# 9/10, train_loss: 0.0684
# 10/10, train_loss: 0.2748
# Epoch 1728 average loss: 0.0885
# Current epoch: 1728 current mean dice: 0.9243 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1729/2000
# 1/10, train_loss: 0.0412
# 2/10, train_loss: 0.0753
# 3/10, train_loss: 0.0532
# 4/10, train_loss: 0.2773
# 5/10, train_loss: 0.0633
# 6/10, train_loss: 0.0588
# 7/10, train_loss: 0.0589
# 8/10, train_loss: 0.0803
# 9/10, train_loss: 0.0658
# 10/10, train_loss: 0.2977
# Epoch 1729 average loss: 0.1072
# ----------
# Epoch 1730/2000
# 1/10, train_loss: 0.0840
# 2/10, train_loss: 0.0627
# 3/10, train_loss: 0.0583
# 4/10, train_loss: 0.0468
# 5/10, train_loss: 0.0502
# 6/10, train_loss: 0.0468
# 7/10, train_loss: 0.0867
# 8/10, train_loss: 0.0739
# 9/10, train_loss: 0.0479
# 10/10, train_loss: 0.0617
# Epoch 1730 average loss: 0.0619
# Current epoch: 1730 current mean dice: 0.9250 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1731/2000
# 1/10, train_loss: 0.1385
# 2/10, train_loss: 0.0414
# 3/10, train_loss: 0.0653
# 4/10, train_loss: 0.0535
# 5/10, train_loss: 0.0886
# 6/10, train_loss: 0.0583
# 7/10, train_loss: 0.0689
# 8/10, train_loss: 0.0749
# 9/10, train_loss: 0.0599
# 10/10, train_loss: 0.0757
# Epoch 1731 average loss: 0.0725
# ----------
# Epoch 1732/2000
# 1/10, train_loss: 0.0482
# 2/10, train_loss: 0.0484
# 3/10, train_loss: 0.0483
# 4/10, train_loss: 0.1028
# 5/10, train_loss: 0.0499
# 6/10, train_loss: 0.0436
# 7/10, train_loss: 0.0655
# 8/10, train_loss: 0.0521
# 9/10, train_loss: 0.0559
# 10/10, train_loss: 0.0526
# Epoch 1732 average loss: 0.0567
# Current epoch: 1732 current mean dice: 0.9254 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1733/2000
# 1/10, train_loss: 0.0510
# 2/10, train_loss: 0.0570
# 3/10, train_loss: 0.0511
# 4/10, train_loss: 0.0628
# 5/10, train_loss: 0.2930
# 6/10, train_loss: 0.1254
# 7/10, train_loss: 0.1073
# 8/10, train_loss: 0.0598
# 9/10, train_loss: 0.0611
# 10/10, train_loss: 0.1177
# Epoch 1733 average loss: 0.0986
# ----------
# Epoch 1734/2000
# 1/10, train_loss: 0.0597
# 2/10, train_loss: 0.0810
# 3/10, train_loss: 0.0534
# 4/10, train_loss: 0.0359
# 5/10, train_loss: 0.2835
# 6/10, train_loss: 0.0569
# 7/10, train_loss: 0.0732
# 8/10, train_loss: 0.0613
# 9/10, train_loss: 0.0663
# 10/10, train_loss: 0.0617
# Epoch 1734 average loss: 0.0833
# Current epoch: 1734 current mean dice: 0.9268 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1735/2000
# 1/10, train_loss: 0.0626
# 2/10, train_loss: 0.0488
# 3/10, train_loss: 0.1060
# 4/10, train_loss: 0.0653
# 5/10, train_loss: 0.0393
# 6/10, train_loss: 0.0864
# 7/10, train_loss: 0.0796
# 8/10, train_loss: 0.0748
# 9/10, train_loss: 0.0500
# 10/10, train_loss: 0.0735
# Epoch 1735 average loss: 0.0686
# ----------
# Epoch 1736/2000
# 1/10, train_loss: 0.0688
# 2/10, train_loss: 0.0715
# 3/10, train_loss: 0.0412
# 4/10, train_loss: 0.0852
# 5/10, train_loss: 0.3342
# 6/10, train_loss: 0.0661
# 7/10, train_loss: 0.0488
# 8/10, train_loss: 0.0699
# 9/10, train_loss: 0.0586
# 10/10, train_loss: 0.0709
# Epoch 1736 average loss: 0.0915
# Current epoch: 1736 current mean dice: 0.9267 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1737/2000
# 1/10, train_loss: 0.2168
# 2/10, train_loss: 0.1099
# 3/10, train_loss: 0.0701
# 4/10, train_loss: 0.0603
# 5/10, train_loss: 0.0424
# 6/10, train_loss: 0.0860
# 7/10, train_loss: 0.0762
# 8/10, train_loss: 0.3054
# 9/10, train_loss: 0.0773
# 10/10, train_loss: 0.0629
# Epoch 1737 average loss: 0.1107
# ----------
# Epoch 1738/2000
# 1/10, train_loss: 0.0352
# 2/10, train_loss: 0.0542
# 3/10, train_loss: 0.0541
# 4/10, train_loss: 0.1229
# 5/10, train_loss: 0.0530
# 6/10, train_loss: 0.0581
# 7/10, train_loss: 0.0449
# 8/10, train_loss: 0.1108
# 9/10, train_loss: 0.0745
# 10/10, train_loss: 0.0579
# Epoch 1738 average loss: 0.0666
# Current epoch: 1738 current mean dice: 0.9227 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1739/2000
# 1/10, train_loss: 0.0714
# 2/10, train_loss: 0.0556
# 3/10, train_loss: 0.0613
# 4/10, train_loss: 0.0431
# 5/10, train_loss: 0.0714
# 6/10, train_loss: 0.0538
# 7/10, train_loss: 0.0854
# 8/10, train_loss: 0.0478
# 9/10, train_loss: 0.0714
# 10/10, train_loss: 0.0463
# Epoch 1739 average loss: 0.0608
# ----------
# Epoch 1740/2000
# 1/10, train_loss: 0.1175
# 2/10, train_loss: 0.0655
# 3/10, train_loss: 0.0364
# 4/10, train_loss: 0.0374
# 5/10, train_loss: 0.2743
# 6/10, train_loss: 0.0749
# 7/10, train_loss: 0.0772
# 8/10, train_loss: 0.0510
# 9/10, train_loss: 0.0519
# 10/10, train_loss: 0.0574
# Epoch 1740 average loss: 0.0844
# Current epoch: 1740 current mean dice: 0.9257 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1741/2000
# 1/10, train_loss: 0.0904
# 2/10, train_loss: 0.0568
# 3/10, train_loss: 0.0603
# 4/10, train_loss: 0.0546
# 5/10, train_loss: 0.0726
# 6/10, train_loss: 0.0577
# 7/10, train_loss: 0.0481
# 8/10, train_loss: 0.0573
# 9/10, train_loss: 0.0526
# 10/10, train_loss: 0.1484
# Epoch 1741 average loss: 0.0699
# ----------
# Epoch 1742/2000
# 1/10, train_loss: 0.0654
# 2/10, train_loss: 0.2747
# 3/10, train_loss: 0.0775
# 4/10, train_loss: 0.0682
# 5/10, train_loss: 0.0766
# 6/10, train_loss: 0.0697
# 7/10, train_loss: 0.0790
# 8/10, train_loss: 0.0976
# 9/10, train_loss: 0.0724
# 10/10, train_loss: 0.0573
# Epoch 1742 average loss: 0.0938
# Current epoch: 1742 current mean dice: 0.9254 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1743/2000
# 1/10, train_loss: 0.0896
# 2/10, train_loss: 0.0662
# 3/10, train_loss: 0.0671
# 4/10, train_loss: 0.0517
# 5/10, train_loss: 0.0856
# 6/10, train_loss: 0.1122
# 7/10, train_loss: 0.0693
# 8/10, train_loss: 0.2916
# 9/10, train_loss: 0.0583
# 10/10, train_loss: 0.0560
# Epoch 1743 average loss: 0.0948
# ----------
# Epoch 1744/2000
# 1/10, train_loss: 0.0793
# 2/10, train_loss: 0.0614
# 3/10, train_loss: 0.0817
# 4/10, train_loss: 0.0372
# 5/10, train_loss: 0.0654
# 6/10, train_loss: 0.0775
# 7/10, train_loss: 0.0670
# 8/10, train_loss: 0.1468
# 9/10, train_loss: 0.0819
# 10/10, train_loss: 0.3202
# Epoch 1744 average loss: 0.1018
# Current epoch: 1744 current mean dice: 0.9227 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1745/2000
# 1/10, train_loss: 0.0904
# 2/10, train_loss: 0.2827
# 3/10, train_loss: 0.0614
# 4/10, train_loss: 0.0814
# 5/10, train_loss: 0.0512
# 6/10, train_loss: 0.0821
# 7/10, train_loss: 0.0519
# 8/10, train_loss: 0.2812
# 9/10, train_loss: 0.0704
# 10/10, train_loss: 0.0582
# Epoch 1745 average loss: 0.1111
# ----------
# Epoch 1746/2000
# 1/10, train_loss: 0.0624
# 2/10, train_loss: 0.0542
# 3/10, train_loss: 0.0655
# 4/10, train_loss: 0.0784
# 5/10, train_loss: 0.2719
# 6/10, train_loss: 0.0659
# 7/10, train_loss: 0.0687
# 8/10, train_loss: 0.0787
# 9/10, train_loss: 0.1044
# 10/10, train_loss: 0.3284
# Epoch 1746 average loss: 0.1179
# Current epoch: 1746 current mean dice: 0.9246 best mean dice: 0.9271 at epoch 1692
# ----------
# Epoch 1747/2000
# 1/10, train_loss: 0.0606
# 2/10, train_loss: 0.0600
# 3/10, train_loss: 0.0889
# 4/10, train_loss: 0.0661
# 5/10, train_loss: 0.0782
# 6/10, train_loss: 0.0675
# 7/10, train_loss: 0.0563
# 8/10, train_loss: 0.0537
# 9/10, train_loss: 0.0908
# 10/10, train_loss: 0.0923
# Epoch 1747 average loss: 0.0714
# ----------
# Epoch 1748/2000
# 1/10, train_loss: 0.1115
# 2/10, train_loss: 0.2820
# 3/10, train_loss: 0.0667
# 4/10, train_loss: 0.1020
# 5/10, train_loss: 0.0553
# 6/10, train_loss: 0.0555
# 7/10, train_loss: 0.0433
# 8/10, train_loss: 0.0663
# 9/10, train_loss: 0.0647
# ...
# 9/10, train_loss: 0.2892
# 10/10, train_loss: 0.0533
# Epoch 1962 average loss: 0.0744
# Current epoch: 1962 current mean dice: 0.9246 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1963/2000
# 1/10, train_loss: 0.0625
# 2/10, train_loss: 0.0657
# 3/10, train_loss: 0.3269
# 4/10, train_loss: 0.0597
# 5/10, train_loss: 0.0684
# 6/10, train_loss: 0.0494
# 7/10, train_loss: 0.0659
# 8/10, train_loss: 0.0822
# 9/10, train_loss: 0.0427
# 10/10, train_loss: 0.0796
# Epoch 1963 average loss: 0.0903
# ----------
# Epoch 1964/2000
# 1/10, train_loss: 0.0663
# 2/10, train_loss: 0.0726
# 3/10, train_loss: 0.0570
# 4/10, train_loss: 0.2853
# 5/10, train_loss: 0.0605
# 6/10, train_loss: 0.0719
# 7/10, train_loss: 0.0616
# 8/10, train_loss: 0.0731
# 9/10, train_loss: 0.0617
# 10/10, train_loss: 0.0506
# Epoch 1964 average loss: 0.0861
# Current epoch: 1964 current mean dice: 0.9256 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1965/2000
# 1/10, train_loss: 0.2934
# 2/10, train_loss: 0.0858
# 3/10, train_loss: 0.0463
# 4/10, train_loss: 0.2852
# 5/10, train_loss: 0.2754
# 6/10, train_loss: 0.0861
# 7/10, train_loss: 0.0576
# 8/10, train_loss: 0.0564
# 9/10, train_loss: 0.0621
# 10/10, train_loss: 0.0583
# Epoch 1965 average loss: 0.1307
# ----------
# Epoch 1966/2000
# 1/10, train_loss: 0.0604
# 2/10, train_loss: 0.0674
# 3/10, train_loss: 0.0504
# 4/10, train_loss: 0.0537
# 5/10, train_loss: 0.0617
# 6/10, train_loss: 0.0958
# 7/10, train_loss: 0.0757
# 8/10, train_loss: 0.0651
# 9/10, train_loss: 0.0641
# 10/10, train_loss: 0.2868
# Epoch 1966 average loss: 0.0881
# Current epoch: 1966 current mean dice: 0.9191 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1967/2000
# 1/10, train_loss: 0.0484
# 2/10, train_loss: 0.0493
# 3/10, train_loss: 0.0501
# 4/10, train_loss: 0.1049
# 5/10, train_loss: 0.0735
# 6/10, train_loss: 0.0494
# 7/10, train_loss: 0.0750
# 8/10, train_loss: 0.0873
# 9/10, train_loss: 0.0694
# 10/10, train_loss: 0.0393
# Epoch 1967 average loss: 0.0647
# ----------
# Epoch 1968/2000
# 1/10, train_loss: 0.0505
# 2/10, train_loss: 0.0614
# 3/10, train_loss: 0.0564
# 4/10, train_loss: 0.0552
# 5/10, train_loss: 0.0700
# 6/10, train_loss: 0.0464
# 7/10, train_loss: 0.0597
# 8/10, train_loss: 0.0631
# 9/10, train_loss: 0.0424
# 10/10, train_loss: 0.0619
# Epoch 1968 average loss: 0.0567
# Current epoch: 1968 current mean dice: 0.9227 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1969/2000
# 1/10, train_loss: 0.0622
# 2/10, train_loss: 0.0753
# 3/10, train_loss: 0.0429
# 4/10, train_loss: 0.0417
# 5/10, train_loss: 0.0713
# 6/10, train_loss: 0.0681
# 7/10, train_loss: 0.0317
# 8/10, train_loss: 0.0583
# 9/10, train_loss: 0.0791
# 10/10, train_loss: 0.2872
# Epoch 1969 average loss: 0.0818
# ----------
# Epoch 1970/2000
# 1/10, train_loss: 0.0887
# 2/10, train_loss: 0.0388
# 3/10, train_loss: 0.0699
# 4/10, train_loss: 0.0639
# 5/10, train_loss: 0.0623
# 6/10, train_loss: 0.0939
# 7/10, train_loss: 0.1263
# 8/10, train_loss: 0.3116
# 9/10, train_loss: 0.2747
# 10/10, train_loss: 0.0693
# Epoch 1970 average loss: 0.1199
# Current epoch: 1970 current mean dice: 0.9211 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1971/2000
# 1/10, train_loss: 0.0389
# 2/10, train_loss: 0.0721
# 3/10, train_loss: 0.0823
# 4/10, train_loss: 0.0607
# 5/10, train_loss: 0.0668
# 6/10, train_loss: 0.0624
# 7/10, train_loss: 0.0535
# 8/10, train_loss: 0.0482
# 9/10, train_loss: 0.2713
# 10/10, train_loss: 0.0621
# Epoch 1971 average loss: 0.0818
# ----------
# Epoch 1972/2000
# 1/10, train_loss: 0.0599
# 2/10, train_loss: 0.0674
# 3/10, train_loss: 0.0617
# 4/10, train_loss: 0.0615
# 5/10, train_loss: 0.0462
# 6/10, train_loss: 0.0664
# 7/10, train_loss: 0.0823
# 8/10, train_loss: 0.0656
# 9/10, train_loss: 0.0770
# 10/10, train_loss: 0.2962
# Epoch 1972 average loss: 0.0884
# Current epoch: 1972 current mean dice: 0.9232 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1973/2000
# 1/10, train_loss: 0.0698
# 2/10, train_loss: 0.0572
# 3/10, train_loss: 0.1062
# 4/10, train_loss: 0.0673
# 5/10, train_loss: 0.0636
# 6/10, train_loss: 0.0826
# 7/10, train_loss: 0.0696
# 8/10, train_loss: 0.1287
# 9/10, train_loss: 0.0539
# 10/10, train_loss: 0.0658
# Epoch 1973 average loss: 0.0765
# ----------
# Epoch 1974/2000
# 1/10, train_loss: 0.0690
# 2/10, train_loss: 0.0464
# 3/10, train_loss: 0.0548
# 4/10, train_loss: 0.0399
# 5/10, train_loss: 0.2306
# 6/10, train_loss: 0.0760
# 7/10, train_loss: 0.0553
# 8/10, train_loss: 0.0769
# 9/10, train_loss: 0.0660
# 10/10, train_loss: 0.0710
# Epoch 1974 average loss: 0.0786
# Current epoch: 1974 current mean dice: 0.9235 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1975/2000
# 1/10, train_loss: 0.0641
# 2/10, train_loss: 0.0734
# 3/10, train_loss: 0.0782
# 4/10, train_loss: 0.0661
# 5/10, train_loss: 0.0574
# 6/10, train_loss: 0.0803
# 7/10, train_loss: 0.0412
# 8/10, train_loss: 0.0421
# 9/10, train_loss: 0.0698
# 10/10, train_loss: 0.0623
# Epoch 1975 average loss: 0.0635
# ----------
# Epoch 1976/2000
# 1/10, train_loss: 0.0854
# 2/10, train_loss: 0.0913
# 3/10, train_loss: 0.0787
# 4/10, train_loss: 0.0831
# 5/10, train_loss: 0.2922
# 6/10, train_loss: 0.0527
# 7/10, train_loss: 0.0550
# 8/10, train_loss: 0.0752
# 9/10, train_loss: 0.0640
# 10/10, train_loss: 0.0545
# Epoch 1976 average loss: 0.0932
# Current epoch: 1976 current mean dice: 0.9250 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1977/2000
# 1/10, train_loss: 0.0564
# 2/10, train_loss: 0.0907
# 3/10, train_loss: 0.0749
# 4/10, train_loss: 0.1020
# 5/10, train_loss: 0.1547
# 6/10, train_loss: 0.0534
# 7/10, train_loss: 0.0840
# 8/10, train_loss: 0.0423
# 9/10, train_loss: 0.0612
# 10/10, train_loss: 0.0662
# Epoch 1977 average loss: 0.0786
# ----------
# Epoch 1978/2000
# 1/10, train_loss: 0.0597
# 2/10, train_loss: 0.0422
# 3/10, train_loss: 0.0647
# 4/10, train_loss: 0.0635
# 5/10, train_loss: 0.0768
# 6/10, train_loss: 0.0471
# 7/10, train_loss: 0.0486
# 8/10, train_loss: 0.0714
# 9/10, train_loss: 0.0573
# 10/10, train_loss: 0.0572
# Epoch 1978 average loss: 0.0588
# Current epoch: 1978 current mean dice: 0.9248 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1979/2000
# 1/10, train_loss: 0.0681
# 2/10, train_loss: 0.0492
# 3/10, train_loss: 0.2870
# 4/10, train_loss: 0.0578
# 5/10, train_loss: 0.0751
# 6/10, train_loss: 0.0506
# 7/10, train_loss: 0.1207
# 8/10, train_loss: 0.0486
# 9/10, train_loss: 0.0561
# 10/10, train_loss: 0.0712
# Epoch 1979 average loss: 0.0884
# ----------
# Epoch 1980/2000
# 1/10, train_loss: 0.0537
# 2/10, train_loss: 0.0508
# 3/10, train_loss: 0.0713
# 4/10, train_loss: 0.0783
# 5/10, train_loss: 0.0477
# 6/10, train_loss: 0.0490
# 7/10, train_loss: 0.0669
# 8/10, train_loss: 0.0493
# 9/10, train_loss: 0.0519
# 10/10, train_loss: 0.0567
# Epoch 1980 average loss: 0.0576
# Current epoch: 1980 current mean dice: 0.9241 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1981/2000
# 1/10, train_loss: 0.0360
# 2/10, train_loss: 0.0693
# 3/10, train_loss: 0.0668
# 4/10, train_loss: 0.2784
# 5/10, train_loss: 0.0666
# 6/10, train_loss: 0.0587
# 7/10, train_loss: 0.0648
# 8/10, train_loss: 0.0653
# 9/10, train_loss: 0.1136
# 10/10, train_loss: 0.0492
# Epoch 1981 average loss: 0.0869
# ----------
# Epoch 1982/2000
# 1/10, train_loss: 0.0620
# 2/10, train_loss: 0.0564
# 3/10, train_loss: 0.0578
# 4/10, train_loss: 0.2777
# 5/10, train_loss: 0.1022
# 6/10, train_loss: 0.0654
# 7/10, train_loss: 0.0674
# 8/10, train_loss: 0.0706
# 9/10, train_loss: 0.0622
# 10/10, train_loss: 0.0853
# Epoch 1982 average loss: 0.0907
# Current epoch: 1982 current mean dice: 0.9241 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1983/2000
# 1/10, train_loss: 0.0558
# 2/10, train_loss: 0.1077
# 3/10, train_loss: 0.0631
# 4/10, train_loss: 0.0410
# 5/10, train_loss: 0.1100
# 6/10, train_loss: 0.0425
# 7/10, train_loss: 0.0530
# 8/10, train_loss: 0.0557
# 9/10, train_loss: 0.0758
# 10/10, train_loss: 0.0654
# Epoch 1983 average loss: 0.0670
# ----------
# Epoch 1984/2000
# 1/10, train_loss: 0.0602
# 2/10, train_loss: 0.0783
# 3/10, train_loss: 0.0671
# 4/10, train_loss: 0.0666
# 5/10, train_loss: 0.2784
# 6/10, train_loss: 0.2936
# 7/10, train_loss: 0.0799
# 8/10, train_loss: 0.0672
# 9/10, train_loss: 0.1047
# 10/10, train_loss: 0.0877
# Epoch 1984 average loss: 0.1184
# Current epoch: 1984 current mean dice: 0.9243 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1985/2000
# 1/10, train_loss: 0.0435
# 2/10, train_loss: 0.0631
# 3/10, train_loss: 0.0567
# 4/10, train_loss: 0.0596
# 5/10, train_loss: 0.0556
# 6/10, train_loss: 0.0632
# 7/10, train_loss: 0.0717
# 8/10, train_loss: 0.0552
# 9/10, train_loss: 0.0513
# 10/10, train_loss: 0.1263
# Epoch 1985 average loss: 0.0646
# ----------
# Epoch 1986/2000
# 1/10, train_loss: 0.0706
# 2/10, train_loss: 0.0424
# 3/10, train_loss: 0.0324
# 4/10, train_loss: 0.0963
# 5/10, train_loss: 0.1080
# 6/10, train_loss: 0.0733
# 7/10, train_loss: 0.0906
# 8/10, train_loss: 0.0512
# 9/10, train_loss: 0.0952
# 10/10, train_loss: 0.1006
# Epoch 1986 average loss: 0.0761
# Current epoch: 1986 current mean dice: 0.9243 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1987/2000
# 1/10, train_loss: 0.0655
# 2/10, train_loss: 0.1613
# 3/10, train_loss: 0.2816
# 4/10, train_loss: 0.0560
# 5/10, train_loss: 0.0515
# 6/10, train_loss: 0.1050
# 7/10, train_loss: 0.2735
# 8/10, train_loss: 0.0696
# 9/10, train_loss: 0.0732
# 10/10, train_loss: 0.1002
# Epoch 1987 average loss: 0.1237
# ----------
# Epoch 1988/2000
# 1/10, train_loss: 0.0557
# 2/10, train_loss: 0.0593
# 3/10, train_loss: 0.0796
# 4/10, train_loss: 0.0686
# 5/10, train_loss: 0.0656
# 6/10, train_loss: 0.0872
# 7/10, train_loss: 0.0341
# 8/10, train_loss: 0.0885
# 9/10, train_loss: 0.0644
# 10/10, train_loss: 0.0657
# Epoch 1988 average loss: 0.0669
# Current epoch: 1988 current mean dice: 0.9269 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1989/2000
# 1/10, train_loss: 0.0508
# 2/10, train_loss: 0.0920
# 3/10, train_loss: 0.0695
# 4/10, train_loss: 0.2867
# 5/10, train_loss: 0.2754
# 6/10, train_loss: 0.0842
# 7/10, train_loss: 0.0635
# 8/10, train_loss: 0.0642
# 9/10, train_loss: 0.0813
# 10/10, train_loss: 0.0836
# Epoch 1989 average loss: 0.1151
# ----------
# Epoch 1990/2000
# 1/10, train_loss: 0.0529
# 2/10, train_loss: 0.0562
# 3/10, train_loss: 0.0681
# 4/10, train_loss: 0.0587
# 5/10, train_loss: 0.0753
# 6/10, train_loss: 0.0542
# 7/10, train_loss: 0.0765
# 8/10, train_loss: 0.0524
# 9/10, train_loss: 0.0582
# 10/10, train_loss: 0.0876
# Epoch 1990 average loss: 0.0640
# Current epoch: 1990 current mean dice: 0.9258 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1991/2000
# 1/10, train_loss: 0.0870
# 2/10, train_loss: 0.0453
# 3/10, train_loss: 0.0852
# 4/10, train_loss: 0.0571
# 5/10, train_loss: 0.0765
# 6/10, train_loss: 0.0602
# 7/10, train_loss: 0.0587
# 8/10, train_loss: 0.0865
# 9/10, train_loss: 0.0674
# 10/10, train_loss: 0.0547
# Epoch 1991 average loss: 0.0679
# ----------
# Epoch 1992/2000
# 1/10, train_loss: 0.0742
# 2/10, train_loss: 0.0445
# 3/10, train_loss: 0.0762
# 4/10, train_loss: 0.0876
# 5/10, train_loss: 0.0427
# 6/10, train_loss: 0.0627
# 7/10, train_loss: 0.0503
# 8/10, train_loss: 0.0667
# 9/10, train_loss: 0.2886
# 10/10, train_loss: 0.0405
# Epoch 1992 average loss: 0.0834
# Current epoch: 1992 current mean dice: 0.9232 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1993/2000
# 1/10, train_loss: 0.0591
# 2/10, train_loss: 0.0792
# 3/10, train_loss: 0.0497
# 4/10, train_loss: 0.0630
# 5/10, train_loss: 0.0452
# 6/10, train_loss: 0.0845
# 7/10, train_loss: 0.0664
# 8/10, train_loss: 0.1005
# 9/10, train_loss: 0.0641
# 10/10, train_loss: 0.0528
# Epoch 1993 average loss: 0.0664
# ----------
# Epoch 1994/2000
# 1/10, train_loss: 0.1080
# 2/10, train_loss: 0.0707
# 3/10, train_loss: 0.1153
# 4/10, train_loss: 0.0566
# 5/10, train_loss: 0.0753
# 6/10, train_loss: 0.0648
# 7/10, train_loss: 0.0617
# 8/10, train_loss: 0.0658
# 9/10, train_loss: 0.0614
# 10/10, train_loss: 0.0900
# Epoch 1994 average loss: 0.0770
# Current epoch: 1994 current mean dice: 0.9231 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1995/2000
# 1/10, train_loss: 0.2439
# 2/10, train_loss: 0.0576
# 3/10, train_loss: 0.0833
# 4/10, train_loss: 0.0546
# 5/10, train_loss: 0.0426
# 6/10, train_loss: 0.0817
# 7/10, train_loss: 0.0829
# 8/10, train_loss: 0.0614
# 9/10, train_loss: 0.0670
# 10/10, train_loss: 0.0674
# Epoch 1995 average loss: 0.0842
# ----------
# Epoch 1996/2000
# 1/10, train_loss: 0.0514
# 2/10, train_loss: 0.0763
# 3/10, train_loss: 0.0882
# 4/10, train_loss: 0.0699
# 5/10, train_loss: 0.2847
# 6/10, train_loss: 0.2739
# 7/10, train_loss: 0.0739
# 8/10, train_loss: 0.0525
# 9/10, train_loss: 0.1395
# 10/10, train_loss: 0.0448
# Epoch 1996 average loss: 0.1155
# Current epoch: 1996 current mean dice: 0.9264 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1997/2000
# 1/10, train_loss: 0.0499
# 2/10, train_loss: 0.0681
# 3/10, train_loss: 0.0469
# 4/10, train_loss: 0.1888
# 5/10, train_loss: 0.0449
# 6/10, train_loss: 0.1190
# 7/10, train_loss: 0.0549
# 8/10, train_loss: 0.0528
# 9/10, train_loss: 0.0677
# 10/10, train_loss: 0.0442
# Epoch 1997 average loss: 0.0737
# ----------
# Epoch 1998/2000
# 1/10, train_loss: 0.0552
# 2/10, train_loss: 0.0670
# 3/10, train_loss: 0.0581
# 4/10, train_loss: 0.0756
# 5/10, train_loss: 0.0764
# 6/10, train_loss: 0.0616
# 7/10, train_loss: 0.0573
# 8/10, train_loss: 0.0607
# 9/10, train_loss: 0.0903
# 10/10, train_loss: 0.0791
# Epoch 1998 average loss: 0.0681
# Current epoch: 1998 current mean dice: 0.9217 best mean dice: 0.9289 at epoch 1850
# ----------
# Epoch 1999/2000
# 1/10, train_loss: 0.0677
# 2/10, train_loss: 0.0603
# 3/10, train_loss: 0.2727
# 4/10, train_loss: 0.0563
# 5/10, train_loss: 0.0685
# 6/10, train_loss: 0.3106
# 7/10, train_loss: 0.0469
# 8/10, train_loss: 0.0711
# 9/10, train_loss: 0.2779
# 10/10, train_loss: 0.0626
# Epoch 1999 average loss: 0.1295
# ----------
# Epoch 2000/2000
# 1/10, train_loss: 0.0434
# 2/10, train_loss: 0.0553
# 3/10, train_loss: 0.0656
# 4/10, train_loss: 0.0622
# 5/10, train_loss: 0.0462
# 6/10, train_loss: 0.0618
# 7/10, train_loss: 0.0668
# 8/10, train_loss: 0.0477
# 9/10, train_loss: 0.0517
# 10/10, train_loss: 0.3185
# Epoch 2000 average loss: 0.0819
# Current epoch: 2000 current mean dice: 0.9262 best mean dice: 0.9289 at epoch 1850
# Training completed, best_metric: 0.9289 at epoch: 1850
# <ipython-input-1-37e8ae6f068e>:217: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_metric_model_SWINUNETR.pth'))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-37e8ae6f068e> in <cell line: 217>()
#     215
#     216 # Load the best model for evaluation
# --> 217 model.load_state_dict(torch.load('best_metric_model_SWINUNETR.pth'))
#     218
#     219 # Evaluation functions
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1317         pickle_load_args["encoding"] = "utf-8"
#    1318
# -> 1319     with _open_file_like(f, "rb") as opened_file:
#    1320         if _is_zipfile(opened_file):
#    1321             # The zipfile reader is going to advance the current file position.
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in _open_file_like(name_or_buffer, mode)
#     657 def _open_file_like(name_or_buffer, mode):
#     658     if _is_path(name_or_buffer):
# --> 659         return _open_file(name_or_buffer, mode)
#     660     else:
#     661         if "w" in mode:
#
# /usr/local/lib/python3.10/dist-packages/torch/serialization.py in __init__(self, name, mode)
#     638 class _open_file(_opener):
#     639     def __init__(self, name, mode):
# --> 640         super().__init__(open(name, mode))
#     641
#     642     def __exit__(self, *args):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'best_metric_model_SWINUNETR.pth'

# %%
# Install MONAI and other dependencies
# !pip install monai==0.9.1
# !pip install nibabel
# !pip install SimpleITK

# Import necessary libraries
import os
import glob
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import nibabel as nib
import SimpleITK as sitk

import monai
from monai.data import CacheDataset, DataLoader
from monai.transforms import (
    Compose, LoadImaged, EnsureChannelFirstd, ScaleIntensityd,
    SpatialCropd, EnsureTyped, Transform
)
from monai.networks.nets import SwinUNETR
from monai.utils import set_determinism
from monai.visualize import blend_images

from google.colab import drive
drive.mount("/content/drive")

# Set determinism for reproducibility
set_determinism(seed=0)

# Define the data directory
data_dir = '/content/drive/MyDrive/Dataset_Final/'  # Update this path if different

# Function to load data dictionaries
def get_data_dicts(data_dir, set_name):
    data_pattern = os.path.join(data_dir, set_name, 'IBSR_*')
    subject_dirs = glob.glob(data_pattern)
    data_dicts = []

    for subject_dir in subject_dirs:
        subject_name = os.path.basename(subject_dir)
        img_file = os.path.join(subject_dir, '{}.nii.gz'.format(subject_name))
        seg_file = os.path.join(subject_dir, '{}_seg.nii.gz'.format(subject_name))
        data_dicts.append({'image': img_file, 'label': seg_file})

    return data_dicts

# Get training and validation data dictionaries
train_files = get_data_dicts(data_dir, 'Training_Set')
val_files = get_data_dicts(data_dir, 'Validation_Set')

# Custom Transform: CenterSpatialCropd
class CenterSpatialCropd(Transform):
    def __init__(self, keys, roi_size):
        self.keys = keys
        self.roi_size = roi_size

    def __call__(self, data):
        d = dict(data)
        for key in self.keys:
            img = d[key]
            spatial_shape = img.shape[1:]  # Assuming (C, D, H, W)
            center = [dim // 2 for dim in spatial_shape]
            # Apply SpatialCropd with roi_center
            crop = SpatialCropd(keys=[key], roi_size=self.roi_size, roi_center=center)
            d = crop(d)
        return d

# Define validation transformations with deterministic spatial cropping
val_transforms = Compose([
    LoadImaged(keys=['image', 'label']),
    EnsureChannelFirstd(keys=['image', 'label']),
    ScaleIntensityd(keys=['image']),
    CenterSpatialCropd(keys=['image', 'label'], roi_size=[96, 96, 96]),
    EnsureTyped(keys=['image', 'label']),
])

# Use CacheDataset for faster data loading
num_workers = 4  # Adjust based on your system's capabilities

# Create validation dataset and dataloader
val_ds = CacheDataset(
    data=val_files,
    transform=val_transforms,
    cache_rate=1.0,
    num_workers=num_workers
)
val_loader = DataLoader(val_ds, batch_size=1, shuffle=False, num_workers=num_workers)

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the model (using MONAI's SwinUNETR)
model = SwinUNETR(
    in_channels=1,
    out_channels=4,
    img_size=[96, 96, 96],
    feature_size=48,
    use_checkpoint=False,
).to(device)
print("SwinUNETR model instantiated successfully!")

# Load the trained model weights
model_weights_path = '/content/drive/MyDrive/Dataset_Final/best_metric_model_SWIN.pth'  # Update this path
if os.path.exists(model_weights_path):
    model.load_state_dict(torch.load(model_weights_path, map_location=device))
    print(f"Loaded model weights from {model_weights_path}")
else:
    raise FileNotFoundError(f"Model weights not found at {model_weights_path}. Please check the path.")

# Define evaluation functions
def compute_dice_coefficient(in1, in2, label=1):
    in1 = in1 == label
    in2 = in2 == label
    intersection = np.logical_and(in1, in2).sum()
    volumes = in1.sum() + in2.sum()
    if volumes == 0:
        return np.NaN
    else:
        return 2. * intersection / volumes

def compute_hausdorff_distance(in1, in2, label=1):
    in1 = (in1 == label).astype(np.uint8)
    in2 = (in2 == label).astype(np.uint8)
    in1_sitk = sitk.GetImageFromArray(in1)
    in2_sitk = sitk.GetImageFromArray(in2)
    hausdorff_distance_filter = sitk.HausdorffDistanceImageFilter()
    hausdorff_distance_filter.Execute(in1_sitk, in2_sitk)
    return hausdorff_distance_filter.GetHausdorffDistance()

def compute_volumetric_difference(in1, in2, label=1):
    in1 = in1 == label
    in2 = in2 == label
    vol1 = in1.sum()
    vol2 = in2.sum()
    if vol1 + vol2 == 0:
        return np.NaN
    else:
        return abs(vol1 - vol2) / (vol1 + vol2)

# Function to resample image to match reference image
def resample_to_match(image, reference_image):
    resampler = sitk.ResampleImageFilter()
    resampler.SetReferenceImage(reference_image)
    resampler.SetInterpolator(sitk.sitkNearestNeighbor)
    resampled_image = resampler.Execute(image)
    return resampled_image

# Directory to save the segmented outputs
output_dir = '/content/drive/MyDrive/Segmented_Outputs/'  # Update this path as needed
os.makedirs(output_dir, exist_ok=True)

# Evaluate on validation data
model.eval()
dice_scores = {i: [] for i in range(4)}
hausdorff_distances = {i: [] for i in range(4)}
volumetric_differences = {i: [] for i in range(4)}

with torch.no_grad():
    for idx, val_data in enumerate(val_loader):
        val_images = val_data['image'].to(device)
        val_labels = val_data['label'].cpu().numpy()
        outputs = model(val_images)
        outputs = torch.argmax(F.softmax(outputs, dim=1), dim=1).cpu().numpy()

        # Save the segmented output before resampling for visualization
        segmented_output_unresampled = outputs[0].astype(np.uint8)
        unresampled_output_file = os.path.join(output_dir, f"segmented_sample_{idx + 1}_cropped.nii.gz")
        # Create a SimpleITK image
        segmented_image_unresampled = sitk.GetImageFromArray(segmented_output_unresampled)
        # Copy the image information from the cropped image
        cropped_image_sitk = sitk.GetImageFromArray(val_data['image'][0].cpu().numpy()[0])
        segmented_image_unresampled.CopyInformation(cropped_image_sitk)
        # Save the image
        sitk.WriteImage(segmented_image_unresampled, unresampled_output_file)

        # Now proceed with resampling and saving the full-size segmentation
        segmented_image = sitk.GetImageFromArray(outputs[0].astype(np.uint8))
        original_image = sitk.ReadImage(val_data['image_meta_dict']['filename_or_obj'][0])

        # Resample segmented image to match the original image's size
        if segmented_image.GetSize() != original_image.GetSize():
            segmented_image = resample_to_match(segmented_image, original_image)

        # Copy metadata
        segmented_image.CopyInformation(original_image)
        output_file = os.path.join(output_dir, f"segmented_sample_{idx + 1}.nii.gz")
        sitk.WriteImage(segmented_image, output_file)
        print(f"Saved segmented output for sample {idx + 1} to {output_file}")

        # Calculate metrics
        for label in range(4):
            dice = compute_dice_coefficient(outputs[0], val_labels[0][0], label=label)
            hd = compute_hausdorff_distance(outputs[0], val_labels[0][0], label=label)
            vd = compute_volumetric_difference(outputs[0], val_labels[0][0], label=label)
            if not np.isnan(dice):
                dice_scores[label].append(dice)
            if not np.isnan(hd):
                hausdorff_distances[label].append(hd)
            if not np.isnan(vd):
                volumetric_differences[label].append(vd)
        print(f"Processed {idx + 1}/{len(val_loader)} validation samples.")

# Compute average metrics per class
print("\n--- Evaluation Metrics on Validation Set ---")
for label in range(4):
    avg_dice = np.mean(dice_scores[label]) if dice_scores[label] else np.NaN
    avg_hd = np.mean(hausdorff_distances[label]) if hausdorff_distances[label] else np.NaN
    avg_vd = np.mean(volumetric_differences[label]) if volumetric_differences[label] else np.NaN
    print(f"Class {label}:")
    print(f"\tDice Coefficient = {avg_dice:.4f}")
    print(f"\tHausdorff Distance = {avg_hd:.4f}")
    print(f"\tVolumetric Difference = {avg_vd:.4f}")

# Visualization using MONAI
def visualize_monai(sample_index, slice_index, val_ds, output_dir):
    data = val_ds[sample_index]
    image = data['image']  # Shape: (C, D, H, W)
    label = data['label']  # Shape: (C, D, H, W)
    segmented_output_path = os.path.join(output_dir, f"segmented_sample_{sample_index + 1}_cropped.nii.gz")
    segmented_output = nib.load(segmented_output_path).get_fdata()

    # Convert numpy arrays to torch tensors
    image_tensor = torch.from_numpy(image).float()
    label_tensor = torch.from_numpy(label).float()
    segmented_output_tensor = torch.from_numpy(segmented_output[np.newaxis, ...]).float()  # Add channel dimension

    # Normalize image for visualization
    image_tensor = (image_tensor - image_tensor.min()) / (image_tensor.max() - image_tensor.min())

    # Select the slice
    # Assuming slice_index corresponds to the D dimension
    image_slice = image_tensor[0, slice_index, :, :]  # Shape: (H, W)
    label_slice = label_tensor[0, slice_index, :, :]  # Shape: (H, W)
    segmented_slice = segmented_output_tensor[0, slice_index, :, :]  # Shape: (H, W)

    # Blend images
    blended_gt = blend_images(image_slice.unsqueeze(0), label_slice.unsqueeze(0), alpha=0.5)
    blended_pred = blend_images(image_slice.unsqueeze(0), segmented_slice.unsqueeze(0), alpha=0.5)

    # Convert blended images to (H, W, C)
    blended_gt_np = blended_gt.squeeze().permute(1, 2, 0).numpy()
    blended_pred_np = blended_pred.squeeze().permute(1, 2, 0).numpy()

    # Plot the images
    fig, axs = plt.subplots(1, 2, figsize=(12, 6))

    axs[0].imshow(blended_gt_np)
    axs[0].set_title('Original with Ground Truth')
    axs[0].axis('off')

    axs[1].imshow(blended_pred_np)
    axs[1].set_title('Original with Predicted Segmentation')
    axs[1].axis('off')

    plt.show()

# Example usage:
# sample_index = 0  # Index of the sample in the validation dataset
# slice_index = 48  # Index of the slice to visualize (should be within the D dimension range)

# visualize_monai(sample_index, slice_index, val_ds, output_dir)
# Out:
# Requirement already satisfied: monai==0.9.1 in /usr/local/lib/python3.10/dist-packages (0.9.1)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from monai==0.9.1) (2.5.1+cu121)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from monai==0.9.1) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.7->monai==0.9.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->monai==0.9.1) (3.0.2)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (5.3.2)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.10/dist-packages (from nibabel) (6.4.5)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from nibabel) (1.26.4)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from nibabel) (4.12.2)
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading dataset: 100%|██████████| 5/5 [00:00<00:00,  6.50it/s]
# SwinUNETR model instantiated successfully!
# <ipython-input-11-aec94bd09fc4>:107: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_weights_path, map_location=device))
# Loaded model weights from /content/drive/MyDrive/Dataset_Final/best_metric_model_SWIN.pth
# Saved segmented output for sample 1 to /content/drive/MyDrive/Segmented_Outputs/segmented_sample_1.nii.gz
# Processed 1/5 validation samples.
# Saved segmented output for sample 2 to /content/drive/MyDrive/Segmented_Outputs/segmented_sample_2.nii.gz
# Processed 2/5 validation samples.
# Saved segmented output for sample 3 to /content/drive/MyDrive/Segmented_Outputs/segmented_sample_3.nii.gz
# Processed 3/5 validation samples.
# Saved segmented output for sample 4 to /content/drive/MyDrive/Segmented_Outputs/segmented_sample_4.nii.gz
# Processed 4/5 validation samples.
# Saved segmented output for sample 5 to /content/drive/MyDrive/Segmented_Outputs/segmented_sample_5.nii.gz
# Processed 5/5 validation samples.
#
# --- Evaluation Metrics on Validation Set ---
# Class 0:
# 	Dice Coefficient = 0.9490
# 	Hausdorff Distance = 19.4543
# 	Volumetric Difference = 0.0205
# Class 1:
# 	Dice Coefficient = 0.9019
# 	Hausdorff Distance = 19.6174
# 	Volumetric Difference = 0.0239
# Class 2:
# 	Dice Coefficient = 0.9370
# 	Hausdorff Distance = 9.0282
# 	Volumetric Difference = 0.0124
# Class 3:
# 	Dice Coefficient = 0.9400
# 	Hausdorff Distance = 7.6924
# 	Volumetric Difference = 0.0220

# %%
# Install MONAI and other dependencies
# !pip install monai==0.9.1
# !pip install nibabel
# !pip install SimpleITK

# Import necessary libraries
import os
import glob
import numpy as np
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt
import nibabel as nib
import SimpleITK as sitk

import monai
from monai.data import CacheDataset, DataLoader
from monai.transforms import (
    Compose, LoadImaged, EnsureChannelFirstd, ScaleIntensityd,
    RandSpatialCropd, RandFlipd, RandRotate90d,
    EnsureTyped
)
from monai.metrics import DiceMetric
from monai.losses import DiceLoss
from monai.networks.nets import UNet
from monai.networks.layers import Norm
from monai.utils import set_determinism

from google.colab import drive
drive.mount("/content/drive")

# Set determinism for reproducibility
set_determinism(seed=0)

# Define the data directory
data_dir = '/content/drive/MyDrive/Dataset_Final/'  # Update this path if different

# Function to load data dictionaries
def get_data_dicts(data_dir, set_name):
    data_pattern = os.path.join(data_dir, set_name, 'IBSR_*')
    subject_dirs = glob.glob(data_pattern)
    data_dicts = []

    for subject_dir in subject_dirs:
        subject_name = os.path.basename(subject_dir)
        img_file = os.path.join(subject_dir, '{}.nii.gz'.format(subject_name))
        seg_file = os.path.join(subject_dir, '{}_seg.nii.gz'.format(subject_name))
        data_dicts.append({'image': img_file, 'label': seg_file})

    return data_dicts

# Get training and validation data dictionaries
train_files = get_data_dicts(data_dir, 'Training_Set')
val_files = get_data_dicts(data_dir, 'Validation_Set')

# Define training transformations
train_transforms = Compose([
    LoadImaged(keys=['image', 'label']),
    EnsureChannelFirstd(keys=['image', 'label']),
    ScaleIntensityd(keys=['image']),
    RandSpatialCropd(keys=['image', 'label'], roi_size=(96, 96, 96), random_size=False),
    RandFlipd(keys=['image', 'label'], prob=0.5, spatial_axis=0),
    RandRotate90d(keys=['image', 'label'], prob=0.5, max_k=3),
    EnsureTyped(keys=['image', 'label']),
])

# Define validation transformations
val_transforms = Compose([
    LoadImaged(keys=['image', 'label']),
    EnsureChannelFirstd(keys=['image', 'label']),
    ScaleIntensityd(keys=['image']),
    EnsureTyped(keys=['image', 'label']),
])

# Use CacheDataset for faster data loading
num_workers = 4  # Adjust based on your system's capabilities

# Create training and validation datasets and dataloaders
train_ds = CacheDataset(
    data=train_files,
    transform=train_transforms,
    cache_rate=1.0,  # Cache all data
    num_workers=num_workers
)
train_loader = DataLoader(train_ds, batch_size=1, shuffle=True, num_workers=num_workers)

val_ds = CacheDataset(
    data=val_files,
    transform=val_transforms,
    cache_rate=1.0,  # Cache all data
    num_workers=num_workers
)
val_loader = DataLoader(val_ds, batch_size=1, shuffle=False, num_workers=num_workers)

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# Define the model (using MONAI's UNet)
model = UNet(
    dimensions=3,
    in_channels=1,
    out_channels=4,  # Number of classes
    channels=(32, 64, 128, 256, 512),
    strides=(2, 2, 2, 2),
    num_res_units=2,
    norm=Norm.BATCH,
).to(device)

# Optionally, load pre-trained weights if available
# model.load_state_dict(torch.load('/path/to/pretrained/model.pth'))

# Define loss function and optimizer
loss_function = DiceLoss(to_onehot_y=True, softmax=True)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)

# Define metric for evaluation without to_onehot_y and softmax
dice_metric = DiceMetric(
    include_background=True,
    reduction="mean",
    get_not_nans=False,
)

# Training loop
max_epochs = 1000
val_interval = 2  # Do validation every 2 epochs
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = []
metric_values = []

for epoch in range(max_epochs):
    print('-' * 10)
    print('Epoch {}/{}'.format(epoch + 1, max_epochs))
    model.train()
    epoch_loss = 0
    step = 0
    for batch_data in train_loader:
        step += 1
        inputs, labels = batch_data['image'].to(device), batch_data['label'].to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
        print('{}/{}, train_loss: {:.4f}'.format(step, len(train_loader), loss.item()))
    epoch_loss /= step
    epoch_loss_values.append(epoch_loss)
    print('Epoch {} average loss: {:.4f}'.format(epoch + 1, epoch_loss))

    if (epoch + 1) % val_interval == 0:
        model.eval()
        with torch.no_grad():
            metric_sum = 0.0
            metric_count = 0
            for val_data in val_loader:
                val_images = val_data['image'].to(device)
                val_labels = val_data['label'].to(device)
                val_outputs = model(val_images)

                # Apply softmax to model outputs
                val_outputs_softmax = F.softmax(val_outputs, dim=1)

                # Convert labels to one-hot encoding
                # Ensure labels are of type LongTensor
                val_labels_onehot = F.one_hot(val_labels.squeeze(1).long(), num_classes=4)  # Shape: (1, H, W, D, C)
                val_labels_onehot = val_labels_onehot.permute(0, 4, 1, 2, 3).float()  # Shape: (1, C, H, W, D)

                # Update DiceMetric
                dice_metric(y_pred=val_outputs_softmax, y=val_labels_onehot)

                metric_count += 1

            # Compute the mean dice score
            metric = dice_metric.aggregate().item()
            dice_metric.reset()
            metric_values.append(metric)

            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(model.state_dict(), 'best_metric_model.pth')
                print('Saved new best metric model')
            print('Current epoch: {} current mean dice: {:.4f} best mean dice: {:.4f} at epoch {}'.format(
                epoch + 1, metric, best_metric, best_metric_epoch))

print('Training completed, best_metric: {:.4f} at epoch: {}'.format(best_metric, best_metric_epoch))

# Load the best model for evaluation
model.load_state_dict(torch.load('best_metric_model.pth'))

# Evaluation functions
def compute_dice_coefficient(in1, in2, label=1):
    in1 = in1 == label
    in2 = in2 == label
    intersection = np.logical_and(in1, in2).sum()
    volumes = in1.sum() + in2.sum()
    if volumes == 0:
        return np.NaN
    else:
        return 2. * intersection / volumes

def compute_hausdorff_distance(in1, in2, label=1):
    in1 = (in1 == label).astype(np.uint8)
    in2 = (in2 == label).astype(np.uint8)
    in1_sitk = sitk.GetImageFromArray(in1)
    in2_sitk = sitk.GetImageFromArray(in2)
    hausdorff_distance_filter = sitk.HausdorffDistanceImageFilter()
    hausdorff_distance_filter.Execute(in1_sitk, in2_sitk)
    return hausdorff_distance_filter.GetHausdorffDistance()

def compute_volumetric_difference(in1, in2, label=1):
    in1 = in1 == label
    in2 = in2 == label
    vol1 = in1.sum()
    vol2 = in2.sum()
    if vol1 + vol2 == 0:
        return np.NaN
    else:
        return abs(vol1 - vol2) / (vol1 + vol2)

# Evaluate on validation data
model.eval()
dice_scores = {i: [] for i in range(4)}  # Assuming 4 classes
hausdorff_distances = {i: [] for i in range(4)}
volumetric_differences = {i: [] for i in range(4)}

with torch.no_grad():
    for val_data in val_loader:
        val_images = val_data['image'].to(device)
        val_labels = val_data['label'].cpu().numpy()
        outputs = model(val_images)
        outputs = torch.argmax(F.softmax(outputs, dim=1), dim=1).cpu().numpy()  # Shape: (1, H, W, D)

        for label in range(4):  # For each class
            dice = compute_dice_coefficient(outputs[0], val_labels[0][0], label=label)
            hd = compute_hausdorff_distance(outputs[0], val_labels[0][0], label=label)
            vd = compute_volumetric_difference(outputs[0], val_labels[0][0], label=label)
            if not np.isnan(dice):
                dice_scores[label].append(dice)
            if not np.isnan(hd):
                hausdorff_distances[label].append(hd)
            if not np.isnan(vd):
                volumetric_differences[label].append(vd)

# Compute average metrics per class
for label in range(4):
    avg_dice = np.mean(dice_scores[label]) if dice_scores[label] else np.NaN
    avg_hd = np.mean(hausdorff_distances[label]) if hausdorff_distances[label] else np.NaN
    avg_vd = np.mean(volumetric_differences[label]) if volumetric_differences[label] else np.NaN
    print(f"Class {label}:")
    print(f"\tDice Coefficient = {avg_dice:.4f}")
    print(f"\tHausdorff Distance = {avg_hd:.4f}")
    print(f"\tVolumetric Difference = {avg_vd:.4f}")
# Out:
# Collecting monai==0.9.1
#   Using cached monai-0.9.1-202207251608-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.10/dist-packages (from monai==0.9.1) (2.5.1+cu121)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from monai==0.9.1) (1.26.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (2024.10.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.7->monai==0.9.1) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.7->monai==0.9.1) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.7->monai==0.9.1) (3.0.2)
# Using cached monai-0.9.1-202207251608-py3-none-any.whl (990 kB)
# Installing collected packages: monai
#   Attempting uninstall: monai
#     Found existing installation: monai 1.4.0
#     Uninstalling monai-1.4.0:
#       Successfully uninstalled monai-1.4.0
# Successfully installed monai-0.9.1
# Requirement already satisfied: nibabel in /usr/local/lib/python3.10/dist-packages (5.3.2)
# Requirement already satisfied: importlib-resources>=5.12 in /usr/local/lib/python3.10/dist-packages (from nibabel) (6.4.5)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.10/dist-packages (from nibabel) (1.26.4)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.10/dist-packages (from nibabel) (24.2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.10/dist-packages (from nibabel) (4.12.2)
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Loading dataset:   0%|          | 0/10 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/monai/data/utils.py:766: UserWarning: Modifying image pixdim from [0.8370536 1.5       0.8370536 0.       ] to [  0.8370536   1.5         0.8370536 213.4510119]
#   warnings.warn(f"Modifying image pixdim from {pixdim} to {norm}")
# /usr/local/lib/python3.10/dist-packages/monai/data/utils.py:766: UserWarning: Modifying image pixdim from [1.  1.5 1.  0. ] to [  1.           1.5          1.         255.00196078]
#   warnings.warn(f"Modifying image pixdim from {pixdim} to {norm}")
# /usr/local/lib/python3.10/dist-packages/monai/data/utils.py:766: UserWarning: Modifying image pixdim from [0.9375 1.5    0.9375 0.    ] to [  0.9375       1.5          0.9375     239.06459149]
#   warnings.warn(f"Modifying image pixdim from {pixdim} to {norm}")
# Loading dataset: 100%|██████████| 10/10 [00:01<00:00,  7.01it/s]
# Loading dataset: 100%|██████████| 5/5 [00:00<00:00,  5.78it/s]
# ----------
# Epoch 1/1000
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1512: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1512: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1512: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/torch/_tensor.py:1512: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   ret = func(*args, **kwargs)
# /usr/local/lib/python3.10/dist-packages/monai/data/__init__.py:117: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   t = cls([], dtype=storage.dtype, device=storage.device)
# 1/10, train_loss: 0.7879
# 2/10, train_loss: 0.8550
# 3/10, train_loss: 0.7899
# 4/10, train_loss: 0.8124
# 5/10, train_loss: 0.8008
# 6/10, train_loss: 0.7958
# 7/10, train_loss: 0.8105
# 8/10, train_loss: 0.7937
# 9/10, train_loss: 0.8449
# 10/10, train_loss: 0.7273
# Epoch 1 average loss: 0.8018
# ----------
# Epoch 2/1000
# 1/10, train_loss: 0.7309
# 2/10, train_loss: 0.7582
# 3/10, train_loss: 0.8304
# 4/10, train_loss: 0.7275
# 5/10, train_loss: 0.7030
# 6/10, train_loss: 0.7007
# 7/10, train_loss: 0.7619
# 8/10, train_loss: 0.6929
# 9/10, train_loss: 0.6794
# 10/10, train_loss: 0.7472
# Epoch 2 average loss: 0.7332
# /usr/local/lib/python3.10/dist-packages/monai/metrics/utils.py:219: UserWarning: y_pred should be a binarized tensor.
#   warnings.warn(f"{name} should be a binarized tensor.")
# Streaming output truncated to the last 5000 lines.
# Current epoch: 630 current mean dice: 0.8353 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 631/1000
# 1/10, train_loss: 0.0803
# 2/10, train_loss: 0.0664
# 3/10, train_loss: 0.0705
# 4/10, train_loss: 0.1633
# 5/10, train_loss: 0.0960
# 6/10, train_loss: 0.0605
# 7/10, train_loss: 0.1129
# 8/10, train_loss: 0.0833
# 9/10, train_loss: 0.0761
# 10/10, train_loss: 0.0779
# Epoch 631 average loss: 0.0887
# ----------
# Epoch 632/1000
# 1/10, train_loss: 0.1041
# 2/10, train_loss: 0.0747
# 3/10, train_loss: 0.1139
# 4/10, train_loss: 0.1252
# 5/10, train_loss: 0.0900
# 6/10, train_loss: 0.0865
# 7/10, train_loss: 0.0767
# 8/10, train_loss: 0.0746
# 9/10, train_loss: 0.1801
# 10/10, train_loss: 0.0628
# Epoch 632 average loss: 0.0989
# Current epoch: 632 current mean dice: 0.8677 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 633/1000
# 1/10, train_loss: 0.1693
# 2/10, train_loss: 0.1838
# 3/10, train_loss: 0.2310
# 4/10, train_loss: 0.1108
# 5/10, train_loss: 0.0603
# 6/10, train_loss: 0.1032
# 7/10, train_loss: 0.0849
# 8/10, train_loss: 0.0768
# 9/10, train_loss: 0.1389
# 10/10, train_loss: 0.1079
# Epoch 633 average loss: 0.1267
# ----------
# Epoch 634/1000
# 1/10, train_loss: 0.0959
# 2/10, train_loss: 0.2823
# 3/10, train_loss: 0.1394
# 4/10, train_loss: 0.0730
# 5/10, train_loss: 0.1050
# 6/10, train_loss: 0.0719
# 7/10, train_loss: 0.1441
# 8/10, train_loss: 0.0761
# 9/10, train_loss: 0.0780
# 10/10, train_loss: 0.0947
# Epoch 634 average loss: 0.1160
# Current epoch: 634 current mean dice: 0.8312 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 635/1000
# 1/10, train_loss: 0.1036
# 2/10, train_loss: 0.0863
# 3/10, train_loss: 0.0953
# 4/10, train_loss: 0.0860
# 5/10, train_loss: 0.0980
# 6/10, train_loss: 0.1096
# 7/10, train_loss: 0.1063
# 8/10, train_loss: 0.0785
# 9/10, train_loss: 0.0996
# 10/10, train_loss: 0.2982
# Epoch 635 average loss: 0.1161
# ----------
# Epoch 636/1000
# 1/10, train_loss: 0.1215
# 2/10, train_loss: 0.0499
# 3/10, train_loss: 0.1026
# 4/10, train_loss: 0.0843
# 5/10, train_loss: 0.0884
# 6/10, train_loss: 0.1150
# 7/10, train_loss: 0.0610
# 8/10, train_loss: 0.1341
# 9/10, train_loss: 0.1254
# 10/10, train_loss: 0.1215
# Epoch 636 average loss: 0.1004
# Current epoch: 636 current mean dice: 0.8335 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 637/1000
# 1/10, train_loss: 0.0749
# 2/10, train_loss: 0.0724
# 3/10, train_loss: 0.0774
# 4/10, train_loss: 0.1521
# 5/10, train_loss: 0.0716
# 6/10, train_loss: 0.1716
# 7/10, train_loss: 0.0547
# 8/10, train_loss: 0.0683
# 9/10, train_loss: 0.0849
# 10/10, train_loss: 0.0782
# Epoch 637 average loss: 0.0906
# ----------
# Epoch 638/1000
# 1/10, train_loss: 0.0921
# 2/10, train_loss: 0.2383
# 3/10, train_loss: 0.0999
# 4/10, train_loss: 0.0717
# 5/10, train_loss: 0.0809
# 6/10, train_loss: 0.1262
# 7/10, train_loss: 0.0759
# 8/10, train_loss: 0.1200
# 9/10, train_loss: 0.0869
# 10/10, train_loss: 0.3108
# Epoch 638 average loss: 0.1303
# Current epoch: 638 current mean dice: 0.8440 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 639/1000
# 1/10, train_loss: 0.0942
# 2/10, train_loss: 0.0804
# 3/10, train_loss: 0.1465
# 4/10, train_loss: 0.0911
# 5/10, train_loss: 0.0841
# 6/10, train_loss: 0.2938
# 7/10, train_loss: 0.0796
# 8/10, train_loss: 0.0878
# 9/10, train_loss: 0.0946
# 10/10, train_loss: 0.1511
# Epoch 639 average loss: 0.1203
# ----------
# Epoch 640/1000
# 1/10, train_loss: 0.0742
# 2/10, train_loss: 0.0889
# 3/10, train_loss: 0.1370
# 4/10, train_loss: 0.0931
# 5/10, train_loss: 0.2972
# 6/10, train_loss: 0.2797
# 7/10, train_loss: 0.0910
# 8/10, train_loss: 0.1001
# 9/10, train_loss: 0.0844
# 10/10, train_loss: 0.1050
# Epoch 640 average loss: 0.1351
# Current epoch: 640 current mean dice: 0.8419 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 641/1000
# 1/10, train_loss: 0.1098
# 2/10, train_loss: 0.0925
# 3/10, train_loss: 0.3232
# 4/10, train_loss: 0.0856
# 5/10, train_loss: 0.0881
# 6/10, train_loss: 0.0948
# 7/10, train_loss: 0.0982
# 8/10, train_loss: 0.0942
# 9/10, train_loss: 0.0954
# 10/10, train_loss: 0.0689
# Epoch 641 average loss: 0.1151
# ----------
# Epoch 642/1000
# 1/10, train_loss: 0.1296
# 2/10, train_loss: 0.1282
# 3/10, train_loss: 0.0739
# 4/10, train_loss: 0.0758
# 5/10, train_loss: 0.0856
# 6/10, train_loss: 0.0742
# 7/10, train_loss: 0.2848
# 8/10, train_loss: 0.0793
# 9/10, train_loss: 0.1019
# 10/10, train_loss: 0.1032
# Epoch 642 average loss: 0.1137
# Current epoch: 642 current mean dice: 0.8547 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 643/1000
# 1/10, train_loss: 0.3489
# 2/10, train_loss: 0.1165
# 3/10, train_loss: 0.0988
# 4/10, train_loss: 0.0863
# 5/10, train_loss: 0.1191
# 6/10, train_loss: 0.0779
# 7/10, train_loss: 0.1245
# 8/10, train_loss: 0.0527
# 9/10, train_loss: 0.0841
# 10/10, train_loss: 0.0835
# Epoch 643 average loss: 0.1192
# ----------
# Epoch 644/1000
# 1/10, train_loss: 0.2908
# 2/10, train_loss: 0.0987
# 3/10, train_loss: 0.1015
# 4/10, train_loss: 0.0983
# 5/10, train_loss: 0.0913
# 6/10, train_loss: 0.3073
# 7/10, train_loss: 0.0915
# 8/10, train_loss: 0.1846
# 9/10, train_loss: 0.0697
# 10/10, train_loss: 0.1694
# Epoch 644 average loss: 0.1503
# Current epoch: 644 current mean dice: 0.8342 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 645/1000
# 1/10, train_loss: 0.0665
# 2/10, train_loss: 0.0943
# 3/10, train_loss: 0.0686
# 4/10, train_loss: 0.1215
# 5/10, train_loss: 0.1020
# 6/10, train_loss: 0.1012
# 7/10, train_loss: 0.0768
# 8/10, train_loss: 0.0937
# 9/10, train_loss: 0.0902
# 10/10, train_loss: 0.0829
# Epoch 645 average loss: 0.0898
# ----------
# Epoch 646/1000
# 1/10, train_loss: 0.0893
# 2/10, train_loss: 0.0568
# 3/10, train_loss: 0.1076
# 4/10, train_loss: 0.1061
# 5/10, train_loss: 0.0772
# 6/10, train_loss: 0.0704
# 7/10, train_loss: 0.1131
# 8/10, train_loss: 0.1204
# 9/10, train_loss: 0.1118
# 10/10, train_loss: 0.2499
# Epoch 646 average loss: 0.1102
# Current epoch: 646 current mean dice: 0.8255 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 647/1000
# 1/10, train_loss: 0.0796
# 2/10, train_loss: 0.1076
# 3/10, train_loss: 0.1007
# 4/10, train_loss: 0.0748
# 5/10, train_loss: 0.1005
# 6/10, train_loss: 0.1163
# 7/10, train_loss: 0.0830
# 8/10, train_loss: 0.1034
# 9/10, train_loss: 0.0911
# 10/10, train_loss: 0.1510
# Epoch 647 average loss: 0.1008
# ----------
# Epoch 648/1000
# 1/10, train_loss: 0.1469
# 2/10, train_loss: 0.0992
# 3/10, train_loss: 0.0884
# 4/10, train_loss: 0.1045
# 5/10, train_loss: 0.0801
# 6/10, train_loss: 0.0947
# 7/10, train_loss: 0.0782
# 8/10, train_loss: 0.0580
# 9/10, train_loss: 0.1168
# 10/10, train_loss: 0.1061
# Epoch 648 average loss: 0.0973
# Current epoch: 648 current mean dice: 0.8182 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 649/1000
# 1/10, train_loss: 0.1000
# 2/10, train_loss: 0.0465
# 3/10, train_loss: 0.1024
# 4/10, train_loss: 0.0942
# 5/10, train_loss: 0.0946
# 6/10, train_loss: 0.0815
# 7/10, train_loss: 0.0867
# 8/10, train_loss: 0.0984
# 9/10, train_loss: 0.0971
# 10/10, train_loss: 0.0818
# Epoch 649 average loss: 0.0883
# ----------
# Epoch 650/1000
# 1/10, train_loss: 0.0673
# 2/10, train_loss: 0.0682
# 3/10, train_loss: 0.0836
# 4/10, train_loss: 0.0852
# 5/10, train_loss: 0.1052
# 6/10, train_loss: 0.0744
# 7/10, train_loss: 0.1241
# 8/10, train_loss: 0.0824
# 9/10, train_loss: 0.3724
# 10/10, train_loss: 0.0810
# Epoch 650 average loss: 0.1144
# Current epoch: 650 current mean dice: 0.8527 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 651/1000
# 1/10, train_loss: 0.0645
# 2/10, train_loss: 0.0838
# 3/10, train_loss: 0.0901
# 4/10, train_loss: 0.1679
# 5/10, train_loss: 0.0660
# 6/10, train_loss: 0.1220
# 7/10, train_loss: 0.1118
# 8/10, train_loss: 0.1069
# 9/10, train_loss: 0.0764
# 10/10, train_loss: 0.1259
# Epoch 651 average loss: 0.1015
# ----------
# Epoch 652/1000
# 1/10, train_loss: 0.0781
# 2/10, train_loss: 0.1007
# 3/10, train_loss: 0.1072
# 4/10, train_loss: 0.0614
# 5/10, train_loss: 0.0974
# 6/10, train_loss: 0.0492
# 7/10, train_loss: 0.1088
# 8/10, train_loss: 0.1344
# 9/10, train_loss: 0.0824
# 10/10, train_loss: 0.1079
# Epoch 652 average loss: 0.0927
# Current epoch: 652 current mean dice: 0.8563 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 653/1000
# 1/10, train_loss: 0.0803
# 2/10, train_loss: 0.2952
# 3/10, train_loss: 0.1073
# 4/10, train_loss: 0.1211
# 5/10, train_loss: 0.0606
# 6/10, train_loss: 0.0706
# 7/10, train_loss: 0.1004
# 8/10, train_loss: 0.0864
# 9/10, train_loss: 0.0590
# 10/10, train_loss: 0.1098
# Epoch 653 average loss: 0.1091
# ----------
# Epoch 654/1000
# 1/10, train_loss: 0.1046
# 2/10, train_loss: 0.0458
# 3/10, train_loss: 0.0935
# 4/10, train_loss: 0.0985
# 5/10, train_loss: 0.0811
# 6/10, train_loss: 0.0619
# 7/10, train_loss: 0.0833
# 8/10, train_loss: 0.3259
# 9/10, train_loss: 0.0826
# 10/10, train_loss: 0.0989
# Epoch 654 average loss: 0.1076
# Current epoch: 654 current mean dice: 0.8518 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 655/1000
# 1/10, train_loss: 0.0875
# 2/10, train_loss: 0.0533
# 3/10, train_loss: 0.0793
# 4/10, train_loss: 0.1060
# 5/10, train_loss: 0.1038
# 6/10, train_loss: 0.0698
# 7/10, train_loss: 0.1030
# 8/10, train_loss: 0.0908
# 9/10, train_loss: 0.0838
# 10/10, train_loss: 0.3072
# Epoch 655 average loss: 0.1084
# ----------
# Epoch 656/1000
# 1/10, train_loss: 0.0766
# 2/10, train_loss: 0.0828
# 3/10, train_loss: 0.0920
# 4/10, train_loss: 0.0586
# 5/10, train_loss: 0.0711
# 6/10, train_loss: 0.1112
# 7/10, train_loss: 0.0530
# 8/10, train_loss: 0.1025
# 9/10, train_loss: 0.1017
# 10/10, train_loss: 0.0687
# Epoch 656 average loss: 0.0818
# Current epoch: 656 current mean dice: 0.8601 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 657/1000
# 1/10, train_loss: 0.1062
# 2/10, train_loss: 0.1089
# 3/10, train_loss: 0.0509
# 4/10, train_loss: 0.0796
# 5/10, train_loss: 0.0631
# 6/10, train_loss: 0.1098
# 7/10, train_loss: 0.1440
# 8/10, train_loss: 0.0694
# 9/10, train_loss: 0.0847
# 10/10, train_loss: 0.0683
# Epoch 657 average loss: 0.0885
# ----------
# Epoch 658/1000
# 1/10, train_loss: 0.0734
# 2/10, train_loss: 0.2971
# 3/10, train_loss: 0.0766
# 4/10, train_loss: 0.0759
# 5/10, train_loss: 0.0924
# 6/10, train_loss: 0.0805
# 7/10, train_loss: 0.0563
# 8/10, train_loss: 0.0693
# 9/10, train_loss: 0.0684
# 10/10, train_loss: 0.3078
# Epoch 658 average loss: 0.1198
# Current epoch: 658 current mean dice: 0.8301 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 659/1000
# 1/10, train_loss: 0.1272
# 2/10, train_loss: 0.0760
# 3/10, train_loss: 0.1454
# 4/10, train_loss: 0.0914
# 5/10, train_loss: 0.0692
# 6/10, train_loss: 0.0754
# 7/10, train_loss: 0.1890
# 8/10, train_loss: 0.0814
# 9/10, train_loss: 0.0594
# 10/10, train_loss: 0.1107
# Epoch 659 average loss: 0.1025
# ----------
# Epoch 660/1000
# 1/10, train_loss: 0.0901
# 2/10, train_loss: 0.0781
# 3/10, train_loss: 0.0505
# 4/10, train_loss: 0.0658
# 5/10, train_loss: 0.1142
# 6/10, train_loss: 0.1263
# 7/10, train_loss: 0.0888
# 8/10, train_loss: 0.0892
# 9/10, train_loss: 0.1042
# 10/10, train_loss: 0.0982
# Epoch 660 average loss: 0.0905
# Current epoch: 660 current mean dice: 0.8448 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 661/1000
# 1/10, train_loss: 0.0868
# 2/10, train_loss: 0.2359
# 3/10, train_loss: 0.0964
# 4/10, train_loss: 0.0805
# 5/10, train_loss: 0.0708
# 6/10, train_loss: 0.0688
# 7/10, train_loss: 0.0829
# 8/10, train_loss: 0.1225
# 9/10, train_loss: 0.0801
# 10/10, train_loss: 0.1071
# Epoch 661 average loss: 0.1032
# ----------
# Epoch 662/1000
# 1/10, train_loss: 0.0810
# 2/10, train_loss: 0.1230
# 3/10, train_loss: 0.0916
# 4/10, train_loss: 0.0898
# 5/10, train_loss: 0.1463
# 6/10, train_loss: 0.0850
# 7/10, train_loss: 0.0688
# 8/10, train_loss: 0.0966
# 9/10, train_loss: 0.0854
# 10/10, train_loss: 0.3168
# Epoch 662 average loss: 0.1184
# Current epoch: 662 current mean dice: 0.8535 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 663/1000
# 1/10, train_loss: 0.0566
# 2/10, train_loss: 0.1302
# 3/10, train_loss: 0.0627
# 4/10, train_loss: 0.0695
# 5/10, train_loss: 0.0826
# 6/10, train_loss: 0.0831
# 7/10, train_loss: 0.1199
# 8/10, train_loss: 0.0716
# 9/10, train_loss: 0.3001
# 10/10, train_loss: 0.0715
# Epoch 663 average loss: 0.1048
# ----------
# Epoch 664/1000
# 1/10, train_loss: 0.0744
# 2/10, train_loss: 0.0974
# 3/10, train_loss: 0.0967
# 4/10, train_loss: 0.0906
# 5/10, train_loss: 0.1213
# 6/10, train_loss: 0.2133
# 7/10, train_loss: 0.0854
# 8/10, train_loss: 0.1569
# 9/10, train_loss: 0.0866
# 10/10, train_loss: 0.1225
# Epoch 664 average loss: 0.1145
# Current epoch: 664 current mean dice: 0.8086 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 665/1000
# 1/10, train_loss: 0.0911
# 2/10, train_loss: 0.0741
# 3/10, train_loss: 0.1934
# 4/10, train_loss: 0.1356
# 5/10, train_loss: 0.1030
# 6/10, train_loss: 0.1123
# 7/10, train_loss: 0.0884
# 8/10, train_loss: 0.0913
# 9/10, train_loss: 0.1176
# 10/10, train_loss: 0.2864
# Epoch 665 average loss: 0.1293
# ----------
# Epoch 666/1000
# 1/10, train_loss: 0.1214
# 2/10, train_loss: 0.0698
# 3/10, train_loss: 0.0891
# 4/10, train_loss: 0.1225
# 5/10, train_loss: 0.0756
# 6/10, train_loss: 0.1193
# 7/10, train_loss: 0.0935
# 8/10, train_loss: 0.1062
# 9/10, train_loss: 0.1286
# 10/10, train_loss: 0.0981
# Epoch 666 average loss: 0.1024
# Current epoch: 666 current mean dice: 0.8526 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 667/1000
# 1/10, train_loss: 0.1340
# 2/10, train_loss: 0.1464
# 3/10, train_loss: 0.0851
# 4/10, train_loss: 0.1229
# 5/10, train_loss: 0.0702
# 6/10, train_loss: 0.0766
# 7/10, train_loss: 0.0794
# 8/10, train_loss: 0.0942
# 9/10, train_loss: 0.1180
# 10/10, train_loss: 0.0648
# Epoch 667 average loss: 0.0992
# ----------
# Epoch 668/1000
# 1/10, train_loss: 0.0823
# 2/10, train_loss: 0.2361
# 3/10, train_loss: 0.3069
# 4/10, train_loss: 0.0901
# 5/10, train_loss: 0.1175
# 6/10, train_loss: 0.0855
# 7/10, train_loss: 0.0942
# 8/10, train_loss: 0.0539
# 9/10, train_loss: 0.1397
# 10/10, train_loss: 0.1122
# Epoch 668 average loss: 0.1318
# Current epoch: 668 current mean dice: 0.8085 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 669/1000
# 1/10, train_loss: 0.0957
# 2/10, train_loss: 0.1000
# 3/10, train_loss: 0.0970
# 4/10, train_loss: 0.1187
# 5/10, train_loss: 0.0816
# 6/10, train_loss: 0.1089
# 7/10, train_loss: 0.0586
# 8/10, train_loss: 0.0798
# 9/10, train_loss: 0.0994
# 10/10, train_loss: 0.1387
# Epoch 669 average loss: 0.0979
# ----------
# Epoch 670/1000
# 1/10, train_loss: 0.1081
# 2/10, train_loss: 0.2933
# 3/10, train_loss: 0.1326
# 4/10, train_loss: 0.0961
# 5/10, train_loss: 0.0843
# 6/10, train_loss: 0.1104
# 7/10, train_loss: 0.0868
# 8/10, train_loss: 0.0940
# 9/10, train_loss: 0.1114
# 10/10, train_loss: 0.0841
# Epoch 670 average loss: 0.1201
# Current epoch: 670 current mean dice: 0.8199 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 671/1000
# 1/10, train_loss: 0.0862
# 2/10, train_loss: 0.1161
# 3/10, train_loss: 0.0857
# 4/10, train_loss: 0.1046
# 5/10, train_loss: 0.0779
# 6/10, train_loss: 0.0708
# 7/10, train_loss: 0.0625
# 8/10, train_loss: 0.0757
# 9/10, train_loss: 0.0999
# 10/10, train_loss: 0.0789
# Epoch 671 average loss: 0.0858
# ----------
# Epoch 672/1000
# 1/10, train_loss: 0.1376
# 2/10, train_loss: 0.2839
# 3/10, train_loss: 0.0765
# 4/10, train_loss: 0.1620
# 5/10, train_loss: 0.3150
# 6/10, train_loss: 0.2891
# 7/10, train_loss: 0.2862
# 8/10, train_loss: 0.0585
# 9/10, train_loss: 0.1004
# 10/10, train_loss: 0.1482
# Epoch 672 average loss: 0.1857
# Current epoch: 672 current mean dice: 0.8128 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 673/1000
# 1/10, train_loss: 0.0827
# 2/10, train_loss: 0.0538
# 3/10, train_loss: 0.0576
# 4/10, train_loss: 0.0689
# 5/10, train_loss: 0.1300
# 6/10, train_loss: 0.0928
# 7/10, train_loss: 0.1244
# 8/10, train_loss: 0.0744
# 9/10, train_loss: 0.1078
# 10/10, train_loss: 0.0820
# Epoch 673 average loss: 0.0874
# ----------
# Epoch 674/1000
# 1/10, train_loss: 0.2837
# 2/10, train_loss: 0.1022
# 3/10, train_loss: 0.0812
# 4/10, train_loss: 0.3000
# 5/10, train_loss: 0.0641
# 6/10, train_loss: 0.1063
# 7/10, train_loss: 0.0642
# 8/10, train_loss: 0.0881
# 9/10, train_loss: 0.0655
# 10/10, train_loss: 0.0733
# Epoch 674 average loss: 0.1229
# Current epoch: 674 current mean dice: 0.8238 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 675/1000
# 1/10, train_loss: 0.0807
# 2/10, train_loss: 0.0809
# 3/10, train_loss: 0.1184
# 4/10, train_loss: 0.0690
# 5/10, train_loss: 0.0774
# 6/10, train_loss: 0.0981
# 7/10, train_loss: 0.0821
# 8/10, train_loss: 0.0794
# 9/10, train_loss: 0.1539
# 10/10, train_loss: 0.0632
# Epoch 675 average loss: 0.0903
# ----------
# Epoch 676/1000
# 1/10, train_loss: 0.0936
# 2/10, train_loss: 0.0804
# 3/10, train_loss: 0.2701
# 4/10, train_loss: 0.0669
# 5/10, train_loss: 0.0869
# 6/10, train_loss: 0.1190
# 7/10, train_loss: 0.1271
# 8/10, train_loss: 0.0941
# 9/10, train_loss: 0.1217
# 10/10, train_loss: 0.0986
# Epoch 676 average loss: 0.1159
# Current epoch: 676 current mean dice: 0.7414 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 677/1000
# 1/10, train_loss: 0.0577
# 2/10, train_loss: 0.1199
# 3/10, train_loss: 0.0724
# 4/10, train_loss: 0.1153
# 5/10, train_loss: 0.0711
# 6/10, train_loss: 0.3811
# 7/10, train_loss: 0.0706
# 8/10, train_loss: 0.0917
# 9/10, train_loss: 0.1003
# 10/10, train_loss: 0.3578
# Epoch 677 average loss: 0.1438
# ----------
# Epoch 678/1000
# 1/10, train_loss: 0.1330
# 2/10, train_loss: 0.0913
# 3/10, train_loss: 0.0984
# 4/10, train_loss: 0.0897
# 5/10, train_loss: 0.2944
# 6/10, train_loss: 0.0910
# 7/10, train_loss: 0.1387
# 8/10, train_loss: 0.1157
# 9/10, train_loss: 0.1129
# 10/10, train_loss: 0.0973
# Epoch 678 average loss: 0.1263
# Current epoch: 678 current mean dice: 0.8358 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 679/1000
# 1/10, train_loss: 0.1972
# 2/10, train_loss: 0.0706
# 3/10, train_loss: 0.0895
# 4/10, train_loss: 0.0993
# 5/10, train_loss: 0.0936
# 6/10, train_loss: 0.1239
# 7/10, train_loss: 0.0674
# 8/10, train_loss: 0.0896
# 9/10, train_loss: 0.1171
# 10/10, train_loss: 0.0872
# Epoch 679 average loss: 0.1035
# ----------
# Epoch 680/1000
# 1/10, train_loss: 0.1065
# 2/10, train_loss: 0.0482
# 3/10, train_loss: 0.1247
# 4/10, train_loss: 0.1738
# 5/10, train_loss: 0.0713
# 6/10, train_loss: 0.1192
# 7/10, train_loss: 0.0708
# 8/10, train_loss: 0.0902
# 9/10, train_loss: 0.1177
# 10/10, train_loss: 0.0905
# Epoch 680 average loss: 0.1013
# Current epoch: 680 current mean dice: 0.8560 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 681/1000
# 1/10, train_loss: 0.0815
# 2/10, train_loss: 0.1080
# 3/10, train_loss: 0.3014
# 4/10, train_loss: 0.1349
# 5/10, train_loss: 0.1036
# 6/10, train_loss: 0.1492
# 7/10, train_loss: 0.1279
# 8/10, train_loss: 0.0793
# 9/10, train_loss: 0.1015
# 10/10, train_loss: 0.0733
# Epoch 681 average loss: 0.1261
# ----------
# Epoch 682/1000
# 1/10, train_loss: 0.1369
# 2/10, train_loss: 0.1248
# 3/10, train_loss: 0.1173
# 4/10, train_loss: 0.1260
# 5/10, train_loss: 0.0624
# 6/10, train_loss: 0.0554
# 7/10, train_loss: 0.1675
# 8/10, train_loss: 0.0697
# 9/10, train_loss: 0.0862
# 10/10, train_loss: 0.0857
# Epoch 682 average loss: 0.1032
# Current epoch: 682 current mean dice: 0.8184 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 683/1000
# 1/10, train_loss: 0.0782
# 2/10, train_loss: 0.0781
# 3/10, train_loss: 0.0884
# 4/10, train_loss: 0.0503
# 5/10, train_loss: 0.2568
# 6/10, train_loss: 0.1116
# 7/10, train_loss: 0.1362
# 8/10, train_loss: 0.0760
# 9/10, train_loss: 0.0472
# 10/10, train_loss: 0.0937
# Epoch 683 average loss: 0.1016
# ----------
# Epoch 684/1000
# 1/10, train_loss: 0.1546
# 2/10, train_loss: 0.0539
# 3/10, train_loss: 0.1083
# 4/10, train_loss: 0.0867
# 5/10, train_loss: 0.1018
# 6/10, train_loss: 0.1212
# 7/10, train_loss: 0.1097
# 8/10, train_loss: 0.0802
# 9/10, train_loss: 0.1091
# 10/10, train_loss: 0.1472
# Epoch 684 average loss: 0.1073
# Current epoch: 684 current mean dice: 0.8157 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 685/1000
# 1/10, train_loss: 0.1645
# 2/10, train_loss: 0.1143
# 3/10, train_loss: 0.1017
# 4/10, train_loss: 0.0798
# 5/10, train_loss: 0.0812
# 6/10, train_loss: 0.1235
# 7/10, train_loss: 0.0568
# 8/10, train_loss: 0.2441
# 9/10, train_loss: 0.2632
# 10/10, train_loss: 0.0699
# Epoch 685 average loss: 0.1299
# ----------
# Epoch 686/1000
# 1/10, train_loss: 0.1124
# 2/10, train_loss: 0.0823
# 3/10, train_loss: 0.0816
# 4/10, train_loss: 0.0778
# 5/10, train_loss: 0.2842
# 6/10, train_loss: 0.0935
# 7/10, train_loss: 0.0647
# 8/10, train_loss: 0.0783
# 9/10, train_loss: 0.1628
# 10/10, train_loss: 0.1194
# Epoch 686 average loss: 0.1157
# Current epoch: 686 current mean dice: 0.8122 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 687/1000
# 1/10, train_loss: 0.1173
# 2/10, train_loss: 0.1230
# 3/10, train_loss: 0.1552
# 4/10, train_loss: 0.1223
# 5/10, train_loss: 0.0725
# 6/10, train_loss: 0.1398
# 7/10, train_loss: 0.1320
# 8/10, train_loss: 0.1127
# 9/10, train_loss: 0.0642
# 10/10, train_loss: 0.0802
# Epoch 687 average loss: 0.1119
# ----------
# Epoch 688/1000
# 1/10, train_loss: 0.0691
# 2/10, train_loss: 0.0488
# 3/10, train_loss: 0.1109
# 4/10, train_loss: 0.1283
# 5/10, train_loss: 0.2178
# 6/10, train_loss: 0.1005
# 7/10, train_loss: 0.0846
# 8/10, train_loss: 0.1646
# 9/10, train_loss: 0.0860
# 10/10, train_loss: 0.1059
# Epoch 688 average loss: 0.1116
# Current epoch: 688 current mean dice: 0.8654 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 689/1000
# 1/10, train_loss: 0.1062
# 2/10, train_loss: 0.0827
# 3/10, train_loss: 0.0883
# 4/10, train_loss: 0.0985
# 5/10, train_loss: 0.0651
# 6/10, train_loss: 0.3464
# 7/10, train_loss: 0.3061
# 8/10, train_loss: 0.1580
# 9/10, train_loss: 0.2778
# 10/10, train_loss: 0.3631
# Epoch 689 average loss: 0.1892
# ----------
# Epoch 690/1000
# 1/10, train_loss: 0.1109
# 2/10, train_loss: 0.0885
# 3/10, train_loss: 0.2722
# 4/10, train_loss: 0.0820
# 5/10, train_loss: 0.1242
# 6/10, train_loss: 0.0740
# 7/10, train_loss: 0.3508
# 8/10, train_loss: 0.0963
# 9/10, train_loss: 0.0892
# 10/10, train_loss: 0.0595
# Epoch 690 average loss: 0.1348
# Current epoch: 690 current mean dice: 0.8555 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 691/1000
# 1/10, train_loss: 0.1468
# 2/10, train_loss: 0.0933
# 3/10, train_loss: 0.1302
# 4/10, train_loss: 0.0935
# 5/10, train_loss: 0.0957
# 6/10, train_loss: 0.1282
# 7/10, train_loss: 0.0701
# 8/10, train_loss: 0.1602
# 9/10, train_loss: 0.0876
# 10/10, train_loss: 0.1774
# Epoch 691 average loss: 0.1183
# ----------
# Epoch 692/1000
# 1/10, train_loss: 0.1028
# 2/10, train_loss: 0.0939
# 3/10, train_loss: 0.0746
# 4/10, train_loss: 0.0654
# 5/10, train_loss: 0.0960
# 6/10, train_loss: 0.0739
# 7/10, train_loss: 0.0615
# 8/10, train_loss: 0.1272
# 9/10, train_loss: 0.2045
# 10/10, train_loss: 0.0663
# Epoch 692 average loss: 0.0966
# Current epoch: 692 current mean dice: 0.8390 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 693/1000
# 1/10, train_loss: 0.1442
# 2/10, train_loss: 0.1022
# 3/10, train_loss: 0.3114
# 4/10, train_loss: 0.0928
# 5/10, train_loss: 0.1468
# 6/10, train_loss: 0.1032
# 7/10, train_loss: 0.1606
# 8/10, train_loss: 0.0874
# 9/10, train_loss: 0.1014
# 10/10, train_loss: 0.0795
# Epoch 693 average loss: 0.1329
# ----------
# Epoch 694/1000
# 1/10, train_loss: 0.0654
# 2/10, train_loss: 0.1390
# 3/10, train_loss: 0.0602
# 4/10, train_loss: 0.1577
# 5/10, train_loss: 0.0662
# 6/10, train_loss: 0.0560
# 7/10, train_loss: 0.0719
# 8/10, train_loss: 0.2606
# 9/10, train_loss: 0.1309
# 10/10, train_loss: 0.0908
# Epoch 694 average loss: 0.1099
# Current epoch: 694 current mean dice: 0.8239 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 695/1000
# 1/10, train_loss: 0.1319
# 2/10, train_loss: 0.1094
# 3/10, train_loss: 0.1274
# 4/10, train_loss: 0.0916
# 5/10, train_loss: 0.0847
# 6/10, train_loss: 0.1034
# 7/10, train_loss: 0.0837
# 8/10, train_loss: 0.1326
# 9/10, train_loss: 0.0680
# 10/10, train_loss: 0.0717
# Epoch 695 average loss: 0.1004
# ----------
# Epoch 696/1000
# 1/10, train_loss: 0.1112
# 2/10, train_loss: 0.0704
# 3/10, train_loss: 0.0827
# 4/10, train_loss: 0.0589
# 5/10, train_loss: 0.1157
# 6/10, train_loss: 0.1177
# 7/10, train_loss: 0.1803
# 8/10, train_loss: 0.0844
# 9/10, train_loss: 0.0710
# 10/10, train_loss: 0.0810
# Epoch 696 average loss: 0.0973
# Current epoch: 696 current mean dice: 0.8312 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 697/1000
# 1/10, train_loss: 0.0824
# 2/10, train_loss: 0.1063
# 3/10, train_loss: 0.0879
# 4/10, train_loss: 0.0709
# 5/10, train_loss: 0.0694
# 6/10, train_loss: 0.0893
# 7/10, train_loss: 0.0878
# 8/10, train_loss: 0.0755
# 9/10, train_loss: 0.0764
# 10/10, train_loss: 0.0762
# Epoch 697 average loss: 0.0822
# ----------
# Epoch 698/1000
# 1/10, train_loss: 0.0556
# 2/10, train_loss: 0.0737
# 3/10, train_loss: 0.0775
# 4/10, train_loss: 0.0809
# 5/10, train_loss: 0.1580
# 6/10, train_loss: 0.1336
# 7/10, train_loss: 0.1442
# 8/10, train_loss: 0.1184
# 9/10, train_loss: 0.0684
# 10/10, train_loss: 0.0668
# Epoch 698 average loss: 0.0977
# Current epoch: 698 current mean dice: 0.8268 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 699/1000
# 1/10, train_loss: 0.0546
# 2/10, train_loss: 0.2869
# 3/10, train_loss: 0.1335
# 4/10, train_loss: 0.0983
# 5/10, train_loss: 0.1620
# 6/10, train_loss: 0.0495
# 7/10, train_loss: 0.0805
# 8/10, train_loss: 0.0932
# 9/10, train_loss: 0.0726
# 10/10, train_loss: 0.2957
# Epoch 699 average loss: 0.1327
# ----------
# Epoch 700/1000
# 1/10, train_loss: 0.0750
# 2/10, train_loss: 0.0964
# 3/10, train_loss: 0.1299
# 4/10, train_loss: 0.0956
# 5/10, train_loss: 0.0910
# 6/10, train_loss: 0.0903
# 7/10, train_loss: 0.1935
# 8/10, train_loss: 0.0554
# 9/10, train_loss: 0.1004
# 10/10, train_loss: 0.0623
# Epoch 700 average loss: 0.0990
# Current epoch: 700 current mean dice: 0.8272 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 701/1000
# 1/10, train_loss: 0.1709
# 2/10, train_loss: 0.0950
# 3/10, train_loss: 0.0762
# 4/10, train_loss: 0.0760
# 5/10, train_loss: 0.0979
# 6/10, train_loss: 0.0982
# 7/10, train_loss: 0.0798
# 8/10, train_loss: 0.1149
# 9/10, train_loss: 0.0860
# 10/10, train_loss: 0.0976
# Epoch 701 average loss: 0.0993
# ----------
# Epoch 702/1000
# 1/10, train_loss: 0.0763
# 2/10, train_loss: 0.2774
# 3/10, train_loss: 0.0914
# 4/10, train_loss: 0.1072
# 5/10, train_loss: 0.0950
# 6/10, train_loss: 0.2959
# 7/10, train_loss: 0.1040
# 8/10, train_loss: 0.1050
# 9/10, train_loss: 0.0796
# 10/10, train_loss: 0.1248
# Epoch 702 average loss: 0.1356
# Current epoch: 702 current mean dice: 0.8061 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 703/1000
# 1/10, train_loss: 0.0885
# 2/10, train_loss: 0.0724
# 3/10, train_loss: 0.0802
# 4/10, train_loss: 0.1942
# 5/10, train_loss: 0.0824
# 6/10, train_loss: 0.1053
# 7/10, train_loss: 0.1206
# 8/10, train_loss: 0.0724
# 9/10, train_loss: 0.2821
# 10/10, train_loss: 0.0902
# Epoch 703 average loss: 0.1188
# ----------
# Epoch 704/1000
# 1/10, train_loss: 0.1188
# 2/10, train_loss: 0.1697
# 3/10, train_loss: 0.0643
# 4/10, train_loss: 0.0919
# 5/10, train_loss: 0.0831
# 6/10, train_loss: 0.0817
# 7/10, train_loss: 0.0504
# 8/10, train_loss: 0.0785
# 9/10, train_loss: 0.0737
# 10/10, train_loss: 0.0972
# Epoch 704 average loss: 0.0909
# Current epoch: 704 current mean dice: 0.7929 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 705/1000
# 1/10, train_loss: 0.1073
# 2/10, train_loss: 0.1256
# 3/10, train_loss: 0.0918
# 4/10, train_loss: 0.3005
# 5/10, train_loss: 0.1508
# 6/10, train_loss: 0.0834
# 7/10, train_loss: 0.0742
# 8/10, train_loss: 0.1021
# 9/10, train_loss: 0.1029
# 10/10, train_loss: 0.1403
# Epoch 705 average loss: 0.1279
# ----------
# Epoch 706/1000
# 1/10, train_loss: 0.0968
# 2/10, train_loss: 0.0890
# 3/10, train_loss: 0.1688
# 4/10, train_loss: 0.0917
# 5/10, train_loss: 0.1019
# 6/10, train_loss: 0.0661
# 7/10, train_loss: 0.0831
# 8/10, train_loss: 0.0827
# 9/10, train_loss: 0.1272
# 10/10, train_loss: 0.1543
# Epoch 706 average loss: 0.1062
# Current epoch: 706 current mean dice: 0.8330 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 707/1000
# 1/10, train_loss: 0.0809
# 2/10, train_loss: 0.0807
# 3/10, train_loss: 0.1195
# 4/10, train_loss: 0.1276
# 5/10, train_loss: 0.0578
# 6/10, train_loss: 0.1336
# 7/10, train_loss: 0.1181
# 8/10, train_loss: 0.2970
# 9/10, train_loss: 0.1324
# 10/10, train_loss: 0.0570
# Epoch 707 average loss: 0.1205
# ----------
# Epoch 708/1000
# 1/10, train_loss: 0.1034
# 2/10, train_loss: 0.0898
# 3/10, train_loss: 0.0849
# 4/10, train_loss: 0.1665
# 5/10, train_loss: 0.1050
# 6/10, train_loss: 0.0787
# 7/10, train_loss: 0.0951
# 8/10, train_loss: 0.0903
# 9/10, train_loss: 0.0771
# 10/10, train_loss: 0.0583
# Epoch 708 average loss: 0.0949
# Current epoch: 708 current mean dice: 0.8461 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 709/1000
# 1/10, train_loss: 0.0636
# 2/10, train_loss: 0.0927
# 3/10, train_loss: 0.1263
# 4/10, train_loss: 0.0904
# 5/10, train_loss: 0.0992
# 6/10, train_loss: 0.0676
# 7/10, train_loss: 0.1146
# 8/10, train_loss: 0.0957
# 9/10, train_loss: 0.0497
# 10/10, train_loss: 0.0837
# Epoch 709 average loss: 0.0883
# ----------
# Epoch 710/1000
# 1/10, train_loss: 0.0856
# 2/10, train_loss: 0.0834
# 3/10, train_loss: 0.0707
# 4/10, train_loss: 0.1023
# 5/10, train_loss: 0.0661
# 6/10, train_loss: 0.0699
# 7/10, train_loss: 0.0693
# 8/10, train_loss: 0.0789
# 9/10, train_loss: 0.0569
# 10/10, train_loss: 0.0667
# Epoch 710 average loss: 0.0750
# Current epoch: 710 current mean dice: 0.8599 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 711/1000
# 1/10, train_loss: 0.1945
# 2/10, train_loss: 0.0867
# 3/10, train_loss: 0.0872
# 4/10, train_loss: 0.2928
# 5/10, train_loss: 0.2775
# 6/10, train_loss: 0.1348
# 7/10, train_loss: 0.1147
# 8/10, train_loss: 0.0852
# 9/10, train_loss: 0.0779
# 10/10, train_loss: 0.1090
# Epoch 711 average loss: 0.1460
# ----------
# Epoch 712/1000
# 1/10, train_loss: 0.1158
# 2/10, train_loss: 0.0821
# 3/10, train_loss: 0.0830
# 4/10, train_loss: 0.0789
# 5/10, train_loss: 0.0706
# 6/10, train_loss: 0.0769
# 7/10, train_loss: 0.0865
# 8/10, train_loss: 0.1426
# 9/10, train_loss: 0.0824
# 10/10, train_loss: 0.0739
# Epoch 712 average loss: 0.0893
# Current epoch: 712 current mean dice: 0.8265 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 713/1000
# 1/10, train_loss: 0.0727
# 2/10, train_loss: 0.0680
# 3/10, train_loss: 0.1157
# 4/10, train_loss: 0.0762
# 5/10, train_loss: 0.0802
# 6/10, train_loss: 0.1205
# 7/10, train_loss: 0.0854
# 8/10, train_loss: 0.0843
# 9/10, train_loss: 0.1031
# 10/10, train_loss: 0.0900
# Epoch 713 average loss: 0.0896
# ----------
# Epoch 714/1000
# 1/10, train_loss: 0.1185
# 2/10, train_loss: 0.1309
# 3/10, train_loss: 0.0966
# 4/10, train_loss: 0.0634
# 5/10, train_loss: 0.0790
# 6/10, train_loss: 0.1696
# 7/10, train_loss: 0.0621
# 8/10, train_loss: 0.1588
# 9/10, train_loss: 0.1456
# 10/10, train_loss: 0.2970
# Epoch 714 average loss: 0.1321
# Current epoch: 714 current mean dice: 0.8203 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 715/1000
# 1/10, train_loss: 0.0757
# 2/10, train_loss: 0.0600
# 3/10, train_loss: 0.1835
# 4/10, train_loss: 0.0516
# 5/10, train_loss: 0.0770
# 6/10, train_loss: 0.0689
# 7/10, train_loss: 0.1190
# 8/10, train_loss: 0.1015
# 9/10, train_loss: 0.1733
# 10/10, train_loss: 0.2912
# Epoch 715 average loss: 0.1202
# ----------
# Epoch 716/1000
# 1/10, train_loss: 0.0836
# 2/10, train_loss: 0.0664
# 3/10, train_loss: 0.0604
# 4/10, train_loss: 0.0797
# 5/10, train_loss: 0.0912
# 6/10, train_loss: 0.0605
# 7/10, train_loss: 0.1222
# 8/10, train_loss: 0.1521
# 9/10, train_loss: 0.1382
# 10/10, train_loss: 0.2939
# Epoch 716 average loss: 0.1148
# Current epoch: 716 current mean dice: 0.8290 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 717/1000
# 1/10, train_loss: 0.1512
# 2/10, train_loss: 0.1115
# 3/10, train_loss: 0.0793
# 4/10, train_loss: 0.0826
# 5/10, train_loss: 0.1184
# 6/10, train_loss: 0.1100
# 7/10, train_loss: 0.0674
# 8/10, train_loss: 0.0494
# 9/10, train_loss: 0.1066
# 10/10, train_loss: 0.0855
# Epoch 717 average loss: 0.0962
# ----------
# Epoch 718/1000
# 1/10, train_loss: 0.0954
# 2/10, train_loss: 0.0753
# 3/10, train_loss: 0.2603
# 4/10, train_loss: 0.1129
# 5/10, train_loss: 0.1122
# 6/10, train_loss: 0.1143
# 7/10, train_loss: 0.1055
# 8/10, train_loss: 0.1366
# 9/10, train_loss: 0.0969
# 10/10, train_loss: 0.1035
# Epoch 718 average loss: 0.1213
# Current epoch: 718 current mean dice: 0.8448 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 719/1000
# 1/10, train_loss: 0.0690
# 2/10, train_loss: 0.0642
# 3/10, train_loss: 0.1121
# 4/10, train_loss: 0.3451
# 5/10, train_loss: 0.0804
# 6/10, train_loss: 0.0814
# 7/10, train_loss: 0.0726
# 8/10, train_loss: 0.0684
# 9/10, train_loss: 0.0866
# 10/10, train_loss: 0.0902
# Epoch 719 average loss: 0.1070
# ----------
# Epoch 720/1000
# 1/10, train_loss: 0.0800
# 2/10, train_loss: 0.0884
# 3/10, train_loss: 0.0694
# 4/10, train_loss: 0.0788
# 5/10, train_loss: 0.0915
# 6/10, train_loss: 0.0787
# 7/10, train_loss: 0.0985
# 8/10, train_loss: 0.3257
# 9/10, train_loss: 0.0904
# 10/10, train_loss: 0.0676
# Epoch 720 average loss: 0.1069
# Current epoch: 720 current mean dice: 0.8516 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 721/1000
# 1/10, train_loss: 0.1019
# 2/10, train_loss: 0.0944
# 3/10, train_loss: 0.1068
# 4/10, train_loss: 0.0875
# 5/10, train_loss: 0.1187
# 6/10, train_loss: 0.0589
# 7/10, train_loss: 0.0950
# 8/10, train_loss: 0.1036
# 9/10, train_loss: 0.1399
# 10/10, train_loss: 0.0994
# Epoch 721 average loss: 0.1006
# ----------
# Epoch 722/1000
# 1/10, train_loss: 0.3343
# 2/10, train_loss: 0.1389
# 3/10, train_loss: 0.0826
# 4/10, train_loss: 0.0773
# 5/10, train_loss: 0.1659
# 6/10, train_loss: 0.1377
# 7/10, train_loss: 0.0795
# 8/10, train_loss: 0.0674
# 9/10, train_loss: 0.1534
# 10/10, train_loss: 0.1288
# Epoch 722 average loss: 0.1366
# Current epoch: 722 current mean dice: 0.8364 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 723/1000
# 1/10, train_loss: 0.0794
# 2/10, train_loss: 0.0519
# 3/10, train_loss: 0.1127
# 4/10, train_loss: 0.1206
# 5/10, train_loss: 0.0836
# 6/10, train_loss: 0.0742
# 7/10, train_loss: 0.2637
# 8/10, train_loss: 0.0990
# 9/10, train_loss: 0.0813
# 10/10, train_loss: 0.0847
# Epoch 723 average loss: 0.1051
# ----------
# Epoch 724/1000
# 1/10, train_loss: 0.0748
# 2/10, train_loss: 0.1181
# 3/10, train_loss: 0.1284
# 4/10, train_loss: 0.1455
# 5/10, train_loss: 0.0670
# 6/10, train_loss: 0.2853
# 7/10, train_loss: 0.1215
# 8/10, train_loss: 0.1117
# 9/10, train_loss: 0.1081
# 10/10, train_loss: 0.0989
# Epoch 724 average loss: 0.1259
# Current epoch: 724 current mean dice: 0.8593 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 725/1000
# 1/10, train_loss: 0.0990
# 2/10, train_loss: 0.0908
# 3/10, train_loss: 0.0670
# 4/10, train_loss: 0.0773
# 5/10, train_loss: 0.1508
# 6/10, train_loss: 0.1091
# 7/10, train_loss: 0.0581
# 8/10, train_loss: 0.0911
# 9/10, train_loss: 0.0742
# 10/10, train_loss: 0.0881
# Epoch 725 average loss: 0.0905
# ----------
# Epoch 726/1000
# 1/10, train_loss: 0.1362
# 2/10, train_loss: 0.0705
# 3/10, train_loss: 0.0580
# 4/10, train_loss: 0.0798
# 5/10, train_loss: 0.0889
# 6/10, train_loss: 0.1119
# 7/10, train_loss: 0.1204
# 8/10, train_loss: 0.2190
# 9/10, train_loss: 0.0873
# 10/10, train_loss: 0.0930
# Epoch 726 average loss: 0.1065
# Current epoch: 726 current mean dice: 0.8672 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 727/1000
# 1/10, train_loss: 0.2321
# 2/10, train_loss: 0.0784
# 3/10, train_loss: 0.2568
# 4/10, train_loss: 0.0847
# 5/10, train_loss: 0.0739
# 6/10, train_loss: 0.1161
# 7/10, train_loss: 0.0901
# 8/10, train_loss: 0.0904
# 9/10, train_loss: 0.0702
# 10/10, train_loss: 0.3629
# Epoch 727 average loss: 0.1456
# ----------
# Epoch 728/1000
# 1/10, train_loss: 0.0671
# 2/10, train_loss: 0.1132
# 3/10, train_loss: 0.1770
# 4/10, train_loss: 0.3441
# 5/10, train_loss: 0.0681
# 6/10, train_loss: 0.1338
# 7/10, train_loss: 0.0648
# 8/10, train_loss: 0.0645
# 9/10, train_loss: 0.2866
# 10/10, train_loss: 0.0737
# Epoch 728 average loss: 0.1393
# Current epoch: 728 current mean dice: 0.8282 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 729/1000
# 1/10, train_loss: 0.1760
# 2/10, train_loss: 0.0975
# 3/10, train_loss: 0.1382
# 4/10, train_loss: 0.0816
# 5/10, train_loss: 0.1238
# 6/10, train_loss: 0.0998
# 7/10, train_loss: 0.2381
# 8/10, train_loss: 0.1100
# 9/10, train_loss: 0.0783
# 10/10, train_loss: 0.0800
# Epoch 729 average loss: 0.1223
# ----------
# Epoch 730/1000
# 1/10, train_loss: 0.0822
# 2/10, train_loss: 0.1174
# 3/10, train_loss: 0.0913
# 4/10, train_loss: 0.0639
# 5/10, train_loss: 0.0691
# 6/10, train_loss: 0.1355
# 7/10, train_loss: 0.2515
# 8/10, train_loss: 0.0850
# 9/10, train_loss: 0.0894
# 10/10, train_loss: 0.0982
# Epoch 730 average loss: 0.1083
# Current epoch: 730 current mean dice: 0.8288 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 731/1000
# 1/10, train_loss: 0.1341
# 2/10, train_loss: 0.0960
# 3/10, train_loss: 0.1068
# 4/10, train_loss: 0.2488
# 5/10, train_loss: 0.0843
# 6/10, train_loss: 0.0609
# 7/10, train_loss: 0.1256
# 8/10, train_loss: 0.0555
# 9/10, train_loss: 0.0750
# 10/10, train_loss: 0.1743
# Epoch 731 average loss: 0.1161
# ----------
# Epoch 732/1000
# 1/10, train_loss: 0.1018
# 2/10, train_loss: 0.1413
# 3/10, train_loss: 0.1402
# 4/10, train_loss: 0.1155
# 5/10, train_loss: 0.0989
# 6/10, train_loss: 0.0581
# 7/10, train_loss: 0.0917
# 8/10, train_loss: 0.1181
# 9/10, train_loss: 0.0930
# 10/10, train_loss: 0.0741
# Epoch 732 average loss: 0.1033
# Current epoch: 732 current mean dice: 0.8578 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 733/1000
# 1/10, train_loss: 0.0799
# 2/10, train_loss: 0.0865
# 3/10, train_loss: 0.1575
# 4/10, train_loss: 0.0911
# 5/10, train_loss: 0.1792
# 6/10, train_loss: 0.0986
# 7/10, train_loss: 0.0715
# 8/10, train_loss: 0.3020
# 9/10, train_loss: 0.3033
# 10/10, train_loss: 0.0886
# Epoch 733 average loss: 0.1458
# ----------
# Epoch 734/1000
# 1/10, train_loss: 0.0499
# 2/10, train_loss: 0.1174
# 3/10, train_loss: 0.0828
# 4/10, train_loss: 0.3133
# 5/10, train_loss: 0.1182
# 6/10, train_loss: 0.0757
# 7/10, train_loss: 0.2931
# 8/10, train_loss: 0.0684
# 9/10, train_loss: 0.2072
# 10/10, train_loss: 0.0426
# Epoch 734 average loss: 0.1369
# Current epoch: 734 current mean dice: 0.8558 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 735/1000
# 1/10, train_loss: 0.0916
# 2/10, train_loss: 0.0820
# 3/10, train_loss: 0.2851
# 4/10, train_loss: 0.1112
# 5/10, train_loss: 0.0854
# 6/10, train_loss: 0.0923
# 7/10, train_loss: 0.1121
# 8/10, train_loss: 0.0970
# 9/10, train_loss: 0.0847
# 10/10, train_loss: 0.0835
# Epoch 735 average loss: 0.1125
# ----------
# Epoch 736/1000
# 1/10, train_loss: 0.0924
# 2/10, train_loss: 0.0525
# 3/10, train_loss: 0.1239
# 4/10, train_loss: 0.0807
# 5/10, train_loss: 0.0993
# 6/10, train_loss: 0.1348
# 7/10, train_loss: 0.0992
# 8/10, train_loss: 0.0903
# 9/10, train_loss: 0.0710
# 10/10, train_loss: 0.0942
# Epoch 736 average loss: 0.0938
# Current epoch: 736 current mean dice: 0.8551 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 737/1000
# 1/10, train_loss: 0.0840
# 2/10, train_loss: 0.0919
# 3/10, train_loss: 0.0903
# 4/10, train_loss: 0.1229
# 5/10, train_loss: 0.0751
# 6/10, train_loss: 0.0728
# 7/10, train_loss: 0.2910
# 8/10, train_loss: 0.0783
# 9/10, train_loss: 0.1023
# 10/10, train_loss: 0.0876
# Epoch 737 average loss: 0.1096
# ----------
# Epoch 738/1000
# 1/10, train_loss: 0.0958
# 2/10, train_loss: 0.1058
# 3/10, train_loss: 0.0727
# 4/10, train_loss: 0.0917
# 5/10, train_loss: 0.0816
# 6/10, train_loss: 0.0650
# 7/10, train_loss: 0.0602
# 8/10, train_loss: 0.0955
# 9/10, train_loss: 0.0676
# 10/10, train_loss: 0.2093
# Epoch 738 average loss: 0.0945
# Current epoch: 738 current mean dice: 0.8534 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 739/1000
# 1/10, train_loss: 0.0765
# 2/10, train_loss: 0.1801
# 3/10, train_loss: 0.1124
# 4/10, train_loss: 0.1040
# 5/10, train_loss: 0.1999
# 6/10, train_loss: 0.0535
# 7/10, train_loss: 0.0887
# 8/10, train_loss: 0.0849
# 9/10, train_loss: 0.1447
# 10/10, train_loss: 0.1232
# Epoch 739 average loss: 0.1168
# ----------
# Epoch 740/1000
# 1/10, train_loss: 0.0930
# 2/10, train_loss: 0.1251
# 3/10, train_loss: 0.0834
# 4/10, train_loss: 0.0733
# 5/10, train_loss: 0.0703
# 6/10, train_loss: 0.0947
# 7/10, train_loss: 0.0834
# 8/10, train_loss: 0.0932
# 9/10, train_loss: 0.1008
# 10/10, train_loss: 0.0901
# Epoch 740 average loss: 0.0907
# Current epoch: 740 current mean dice: 0.8177 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 741/1000
# 1/10, train_loss: 0.2528
# 2/10, train_loss: 0.1067
# 3/10, train_loss: 0.0811
# 4/10, train_loss: 0.4117
# 5/10, train_loss: 0.0595
# 6/10, train_loss: 0.2079
# 7/10, train_loss: 0.0710
# 8/10, train_loss: 0.0798
# 9/10, train_loss: 0.0511
# 10/10, train_loss: 0.3103
# Epoch 741 average loss: 0.1632
# ----------
# Epoch 742/1000
# 1/10, train_loss: 0.0894
# 2/10, train_loss: 0.2887
# 3/10, train_loss: 0.0847
# 4/10, train_loss: 0.1196
# 5/10, train_loss: 0.1296
# 6/10, train_loss: 0.2086
# 7/10, train_loss: 0.0681
# 8/10, train_loss: 0.1230
# 9/10, train_loss: 0.0742
# 10/10, train_loss: 0.0980
# Epoch 742 average loss: 0.1284
# Current epoch: 742 current mean dice: 0.7875 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 743/1000
# 1/10, train_loss: 0.1070
# 2/10, train_loss: 0.0572
# 3/10, train_loss: 0.1151
# 4/10, train_loss: 0.0926
# 5/10, train_loss: 0.0899
# 6/10, train_loss: 0.0775
# 7/10, train_loss: 0.0749
# 8/10, train_loss: 0.1696
# 9/10, train_loss: 0.0867
# 10/10, train_loss: 0.0752
# Epoch 743 average loss: 0.0946
# ----------
# Epoch 744/1000
# 1/10, train_loss: 0.0737
# 2/10, train_loss: 0.0808
# 3/10, train_loss: 0.0849
# 4/10, train_loss: 0.0770
# 5/10, train_loss: 0.1199
# 6/10, train_loss: 0.2983
# 7/10, train_loss: 0.0715
# 8/10, train_loss: 0.0967
# 9/10, train_loss: 0.0928
# 10/10, train_loss: 0.0644
# Epoch 744 average loss: 0.1060
# Current epoch: 744 current mean dice: 0.8269 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 745/1000
# 1/10, train_loss: 0.0815
# 2/10, train_loss: 0.0701
# 3/10, train_loss: 0.0893
# 4/10, train_loss: 0.0677
# 5/10, train_loss: 0.2635
# 6/10, train_loss: 0.1519
# 7/10, train_loss: 0.0878
# 8/10, train_loss: 0.1170
# 9/10, train_loss: 0.1147
# 10/10, train_loss: 0.1171
# Epoch 745 average loss: 0.1161
# ----------
# Epoch 746/1000
# 1/10, train_loss: 0.3026
# 2/10, train_loss: 0.2497
# 3/10, train_loss: 0.1155
# 4/10, train_loss: 0.0920
# 5/10, train_loss: 0.1019
# 6/10, train_loss: 0.1020
# 7/10, train_loss: 0.0860
# 8/10, train_loss: 0.0940
# 9/10, train_loss: 0.1630
# 10/10, train_loss: 0.1307
# Epoch 746 average loss: 0.1438
# Current epoch: 746 current mean dice: 0.6592 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 747/1000
# 1/10, train_loss: 0.1059
# 2/10, train_loss: 0.3392
# 3/10, train_loss: 0.1118
# 4/10, train_loss: 0.1151
# 5/10, train_loss: 0.3605
# 6/10, train_loss: 0.1177
# 7/10, train_loss: 0.1385
# 8/10, train_loss: 0.2215
# 9/10, train_loss: 0.0868
# 10/10, train_loss: 0.1581
# Epoch 747 average loss: 0.1755
# ----------
# Epoch 748/1000
# 1/10, train_loss: 0.1761
# 2/10, train_loss: 0.2142
# 3/10, train_loss: 0.0692
# 4/10, train_loss: 0.1526
# 5/10, train_loss: 0.1143
# 6/10, train_loss: 0.0962
# 7/10, train_loss: 0.1109
# 8/10, train_loss: 0.1791
# 9/10, train_loss: 0.0849
# 10/10, train_loss: 0.3148
# Epoch 748 average loss: 0.1512
# Current epoch: 748 current mean dice: 0.8372 best mean dice: 0.8711 at epoch 610
# ----------
# Epoch 749/1000
# 1/10, train_loss: 0.1340
# 2/10, train_loss: 0.1676
# 3/10, train_loss: 0.3041
# 4/10, train_loss: 0.1055
# 5/10, train_loss: 0.0892
# 6/10, train_loss: 0.1308
# 7/10, train_loss: 0.1220
# 8/10, train_loss: 0.1655
# 9/10, train_loss: 0.0993
# 10/10, train_loss: 0.0454
# Epoch 749 average loss: 0.1363
# ----------
# Epoch 750/1000
# 1/10, train_loss: 0.0949
# 2/10, train_loss: 0.0861
# 3/10, train_loss: 0.0988
# 4/10, train_loss: 0.0922
# 5/10, train_loss: 0.2408
# 6/10, train_loss: 0.2924
# 7/10, train_loss: 0.0999
# 8/10, train_loss: 0.4456
# 9/10, train_loss: 0.0569
# 10/10, train_loss: 0.1512
# Epoch 750 average loss: 0.1659
# ...
# 3/10, train_loss: 0.0617
# 4/10, train_loss: 0.0609
# 5/10, train_loss: 0.0894
# 6/10, train_loss: 0.2837
# 7/10, train_loss: 0.1106
# 8/10, train_loss: 0.0804
# 9/10, train_loss: 0.0917
# 10/10, train_loss: 0.0717
# Epoch 959 average loss: 0.0971
# ----------
# Epoch 960/1000
# 1/10, train_loss: 0.0693
# 2/10, train_loss: 0.0915
# 3/10, train_loss: 0.0470
# 4/10, train_loss: 0.1112
# 5/10, train_loss: 0.1097
# 6/10, train_loss: 0.1114
# 7/10, train_loss: 0.0914
# 8/10, train_loss: 0.1016
# 9/10, train_loss: 0.0797
# 10/10, train_loss: 0.1103
# Epoch 960 average loss: 0.0923
# Current epoch: 960 current mean dice: 0.8495 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 961/1000
# 1/10, train_loss: 0.0508
# 2/10, train_loss: 0.0868
# 3/10, train_loss: 0.0622
# 4/10, train_loss: 0.0765
# 5/10, train_loss: 0.0651
# 6/10, train_loss: 0.0522
# 7/10, train_loss: 0.0713
# 8/10, train_loss: 0.0860
# 9/10, train_loss: 0.0634
# 10/10, train_loss: 0.0973
# Epoch 961 average loss: 0.0712
# ----------
# Epoch 962/1000
# 1/10, train_loss: 0.0835
# 2/10, train_loss: 0.0756
# 3/10, train_loss: 0.0669
# 4/10, train_loss: 0.0699
# 5/10, train_loss: 0.0496
# 6/10, train_loss: 0.0647
# 7/10, train_loss: 0.0506
# 8/10, train_loss: 0.0653
# 9/10, train_loss: 0.0805
# 10/10, train_loss: 0.0678
# Epoch 962 average loss: 0.0674
# Current epoch: 962 current mean dice: 0.8791 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 963/1000
# 1/10, train_loss: 0.1414
# 2/10, train_loss: 0.0851
# 3/10, train_loss: 0.1256
# 4/10, train_loss: 0.0735
# 5/10, train_loss: 0.0721
# 6/10, train_loss: 0.0944
# 7/10, train_loss: 0.0911
# 8/10, train_loss: 0.0935
# 9/10, train_loss: 0.0721
# 10/10, train_loss: 0.0680
# Epoch 963 average loss: 0.0917
# ----------
# Epoch 964/1000
# 1/10, train_loss: 0.3087
# 2/10, train_loss: 0.3020
# 3/10, train_loss: 0.0990
# 4/10, train_loss: 0.0603
# 5/10, train_loss: 0.1051
# 6/10, train_loss: 0.0704
# 7/10, train_loss: 0.2011
# 8/10, train_loss: 0.0669
# 9/10, train_loss: 0.0740
# 10/10, train_loss: 0.0630
# Epoch 964 average loss: 0.1351
# Current epoch: 964 current mean dice: 0.8601 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 965/1000
# 1/10, train_loss: 0.2037
# 2/10, train_loss: 0.1175
# 3/10, train_loss: 0.0854
# 4/10, train_loss: 0.0786
# 5/10, train_loss: 0.0799
# 6/10, train_loss: 0.2869
# 7/10, train_loss: 0.0607
# 8/10, train_loss: 0.0753
# 9/10, train_loss: 0.0683
# 10/10, train_loss: 0.1493
# Epoch 965 average loss: 0.1205
# ----------
# Epoch 966/1000
# 1/10, train_loss: 0.2886
# 2/10, train_loss: 0.0960
# 3/10, train_loss: 0.0787
# 4/10, train_loss: 0.0584
# 5/10, train_loss: 0.0734
# 6/10, train_loss: 0.0798
# 7/10, train_loss: 0.1623
# 8/10, train_loss: 0.0925
# 9/10, train_loss: 0.0946
# 10/10, train_loss: 0.2957
# Epoch 966 average loss: 0.1320
# Current epoch: 966 current mean dice: 0.8534 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 967/1000
# 1/10, train_loss: 0.0621
# 2/10, train_loss: 0.0953
# 3/10, train_loss: 0.1033
# 4/10, train_loss: 0.1103
# 5/10, train_loss: 0.0646
# 6/10, train_loss: 0.1645
# 7/10, train_loss: 0.0753
# 8/10, train_loss: 0.2961
# 9/10, train_loss: 0.0722
# 10/10, train_loss: 0.0885
# Epoch 967 average loss: 0.1132
# ----------
# Epoch 968/1000
# 1/10, train_loss: 0.0827
# 2/10, train_loss: 0.0792
# 3/10, train_loss: 0.0873
# 4/10, train_loss: 0.0741
# 5/10, train_loss: 0.0525
# 6/10, train_loss: 0.1072
# 7/10, train_loss: 0.0785
# 8/10, train_loss: 0.0867
# 9/10, train_loss: 0.2803
# 10/10, train_loss: 0.1219
# Epoch 968 average loss: 0.1050
# Current epoch: 968 current mean dice: 0.8644 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 969/1000
# 1/10, train_loss: 0.0696
# 2/10, train_loss: 0.3037
# 3/10, train_loss: 0.0783
# 4/10, train_loss: 0.1129
# 5/10, train_loss: 0.0789
# 6/10, train_loss: 0.1013
# 7/10, train_loss: 0.0744
# 8/10, train_loss: 0.0788
# 9/10, train_loss: 0.0834
# 10/10, train_loss: 0.0771
# Epoch 969 average loss: 0.1058
# ----------
# Epoch 970/1000
# 1/10, train_loss: 0.2828
# 2/10, train_loss: 0.0956
# 3/10, train_loss: 0.1326
# 4/10, train_loss: 0.0736
# 5/10, train_loss: 0.0803
# 6/10, train_loss: 0.0593
# 7/10, train_loss: 0.1136
# 8/10, train_loss: 0.0562
# 9/10, train_loss: 0.1186
# 10/10, train_loss: 0.0505
# Epoch 970 average loss: 0.1063
# Current epoch: 970 current mean dice: 0.8629 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 971/1000
# 1/10, train_loss: 0.0845
# 2/10, train_loss: 0.0800
# 3/10, train_loss: 0.0804
# 4/10, train_loss: 0.0938
# 5/10, train_loss: 0.0766
# 6/10, train_loss: 0.0915
# 7/10, train_loss: 0.0675
# 8/10, train_loss: 0.0770
# 9/10, train_loss: 0.1174
# 10/10, train_loss: 0.0436
# Epoch 971 average loss: 0.0812
# ----------
# Epoch 972/1000
# 1/10, train_loss: 0.0634
# 2/10, train_loss: 0.0586
# 3/10, train_loss: 0.1122
# 4/10, train_loss: 0.0620
# 5/10, train_loss: 0.0831
# 6/10, train_loss: 0.0530
# 7/10, train_loss: 0.0708
# 8/10, train_loss: 0.0588
# 9/10, train_loss: 0.1091
# 10/10, train_loss: 0.0843
# Epoch 972 average loss: 0.0755
# Current epoch: 972 current mean dice: 0.8814 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 973/1000
# 1/10, train_loss: 0.0665
# 2/10, train_loss: 0.1007
# 3/10, train_loss: 0.0582
# 4/10, train_loss: 0.0906
# 5/10, train_loss: 0.0696
# 6/10, train_loss: 0.0842
# 7/10, train_loss: 0.0821
# 8/10, train_loss: 0.0858
# 9/10, train_loss: 0.0960
# 10/10, train_loss: 0.0763
# Epoch 973 average loss: 0.0810
# ----------
# Epoch 974/1000
# 1/10, train_loss: 0.0739
# 2/10, train_loss: 0.2843
# 3/10, train_loss: 0.0875
# 4/10, train_loss: 0.0575
# 5/10, train_loss: 0.0633
# 6/10, train_loss: 0.0473
# 7/10, train_loss: 0.0664
# 8/10, train_loss: 0.1100
# 9/10, train_loss: 0.1663
# 10/10, train_loss: 0.0638
# Epoch 974 average loss: 0.1020
# Current epoch: 974 current mean dice: 0.8774 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 975/1000
# 1/10, train_loss: 0.0609
# 2/10, train_loss: 0.0737
# 3/10, train_loss: 0.0807
# 4/10, train_loss: 0.0911
# 5/10, train_loss: 0.1144
# 6/10, train_loss: 0.0936
# 7/10, train_loss: 0.0972
# 8/10, train_loss: 0.0710
# 9/10, train_loss: 0.1106
# 10/10, train_loss: 0.1446
# Epoch 975 average loss: 0.0938
# ----------
# Epoch 976/1000
# 1/10, train_loss: 0.1034
# 2/10, train_loss: 0.3164
# 3/10, train_loss: 0.1026
# 4/10, train_loss: 0.2676
# 5/10, train_loss: 0.0660
# 6/10, train_loss: 0.0947
# 7/10, train_loss: 0.1213
# 8/10, train_loss: 0.2940
# 9/10, train_loss: 0.0903
# 10/10, train_loss: 0.0753
# Epoch 976 average loss: 0.1532
# Current epoch: 976 current mean dice: 0.8203 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 977/1000
# 1/10, train_loss: 0.0719
# 2/10, train_loss: 0.2839
# 3/10, train_loss: 0.1293
# 4/10, train_loss: 0.0737
# 5/10, train_loss: 0.0788
# 6/10, train_loss: 0.1326
# 7/10, train_loss: 0.1082
# 8/10, train_loss: 0.2417
# 9/10, train_loss: 0.0480
# 10/10, train_loss: 0.0831
# Epoch 977 average loss: 0.1251
# ----------
# Epoch 978/1000
# 1/10, train_loss: 0.1418
# 2/10, train_loss: 0.0696
# 3/10, train_loss: 0.1653
# 4/10, train_loss: 0.0862
# 5/10, train_loss: 0.0849
# 6/10, train_loss: 0.0977
# 7/10, train_loss: 0.0741
# 8/10, train_loss: 0.0712
# 9/10, train_loss: 0.2861
# 10/10, train_loss: 0.1131
# Epoch 978 average loss: 0.1190
# Current epoch: 978 current mean dice: 0.8685 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 979/1000
# 1/10, train_loss: 0.2298
# 2/10, train_loss: 0.2958
# 3/10, train_loss: 0.0929
# 4/10, train_loss: 0.1069
# 5/10, train_loss: 0.0767
# 6/10, train_loss: 0.1053
# 7/10, train_loss: 0.1440
# 8/10, train_loss: 0.2957
# 9/10, train_loss: 0.0859
# 10/10, train_loss: 0.0738
# Epoch 979 average loss: 0.1507
# ----------
# Epoch 980/1000
# 1/10, train_loss: 0.0931
# 2/10, train_loss: 0.0813
# 3/10, train_loss: 0.0641
# 4/10, train_loss: 0.2951
# 5/10, train_loss: 0.0784
# 6/10, train_loss: 0.0929
# 7/10, train_loss: 0.1013
# 8/10, train_loss: 0.2075
# 9/10, train_loss: 0.0719
# 10/10, train_loss: 0.0800
# Epoch 980 average loss: 0.1166
# Current epoch: 980 current mean dice: 0.8344 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 981/1000
# 1/10, train_loss: 0.0844
# 2/10, train_loss: 0.0999
# 3/10, train_loss: 0.2461
# 4/10, train_loss: 0.1354
# 5/10, train_loss: 0.0948
# 6/10, train_loss: 0.1215
# 7/10, train_loss: 0.0599
# 8/10, train_loss: 0.0749
# 9/10, train_loss: 0.0678
# 10/10, train_loss: 0.1300
# Epoch 981 average loss: 0.1115
# ----------
# Epoch 982/1000
# 1/10, train_loss: 0.1022
# 2/10, train_loss: 0.0855
# 3/10, train_loss: 0.1086
# 4/10, train_loss: 0.0746
# 5/10, train_loss: 0.0466
# 6/10, train_loss: 0.0969
# 7/10, train_loss: 0.0907
# 8/10, train_loss: 0.0695
# 9/10, train_loss: 0.0665
# 10/10, train_loss: 0.0760
# Epoch 982 average loss: 0.0817
# Current epoch: 982 current mean dice: 0.8457 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 983/1000
# 1/10, train_loss: 0.3204
# 2/10, train_loss: 0.0711
# 3/10, train_loss: 0.1247
# 4/10, train_loss: 0.1018
# 5/10, train_loss: 0.0789
# 6/10, train_loss: 0.0873
# 7/10, train_loss: 0.0694
# 8/10, train_loss: 0.0609
# 9/10, train_loss: 0.0681
# 10/10, train_loss: 0.1320
# Epoch 983 average loss: 0.1115
# ----------
# Epoch 984/1000
# 1/10, train_loss: 0.1108
# 2/10, train_loss: 0.0894
# 3/10, train_loss: 0.1036
# 4/10, train_loss: 0.1424
# 5/10, train_loss: 0.0963
# 6/10, train_loss: 0.1283
# 7/10, train_loss: 0.0707
# 8/10, train_loss: 0.2995
# 9/10, train_loss: 0.0751
# 10/10, train_loss: 0.0737
# Epoch 984 average loss: 0.1190
# Current epoch: 984 current mean dice: 0.8621 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 985/1000
# 1/10, train_loss: 0.1179
# 2/10, train_loss: 0.0761
# 3/10, train_loss: 0.0759
# 4/10, train_loss: 0.0770
# 5/10, train_loss: 0.0801
# 6/10, train_loss: 0.0898
# 7/10, train_loss: 0.0950
# 8/10, train_loss: 0.2051
# 9/10, train_loss: 0.0766
# 10/10, train_loss: 0.2828
# Epoch 985 average loss: 0.1176
# ----------
# Epoch 986/1000
# 1/10, train_loss: 0.1328
# 2/10, train_loss: 0.0651
# 3/10, train_loss: 0.1429
# 4/10, train_loss: 0.0832
# 5/10, train_loss: 0.1268
# 6/10, train_loss: 0.0701
# 7/10, train_loss: 0.1093
# 8/10, train_loss: 0.1206
# 9/10, train_loss: 0.1173
# 10/10, train_loss: 0.1294
# Epoch 986 average loss: 0.1097
# Current epoch: 986 current mean dice: 0.8297 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 987/1000
# 1/10, train_loss: 0.1165
# 2/10, train_loss: 0.1778
# 3/10, train_loss: 0.0879
# 4/10, train_loss: 0.1165
# 5/10, train_loss: 0.0531
# 6/10, train_loss: 0.1028
# 7/10, train_loss: 0.1261
# 8/10, train_loss: 0.0888
# 9/10, train_loss: 0.0792
# 10/10, train_loss: 0.0763
# Epoch 987 average loss: 0.1025
# ----------
# Epoch 988/1000
# 1/10, train_loss: 0.0946
# 2/10, train_loss: 0.0686
# 3/10, train_loss: 0.0597
# 4/10, train_loss: 0.0627
# 5/10, train_loss: 0.0747
# 6/10, train_loss: 0.0683
# 7/10, train_loss: 0.1368
# 8/10, train_loss: 0.0811
# 9/10, train_loss: 0.0837
# 10/10, train_loss: 0.0663
# Epoch 988 average loss: 0.0796
# Current epoch: 988 current mean dice: 0.8296 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 989/1000
# 1/10, train_loss: 0.2967
# 2/10, train_loss: 0.0957
# 3/10, train_loss: 0.0426
# 4/10, train_loss: 0.0566
# 5/10, train_loss: 0.1006
# 6/10, train_loss: 0.1360
# 7/10, train_loss: 0.0604
# 8/10, train_loss: 0.0705
# 9/10, train_loss: 0.0818
# 10/10, train_loss: 0.0861
# Epoch 989 average loss: 0.1027
# ----------
# Epoch 990/1000
# 1/10, train_loss: 0.0664
# 2/10, train_loss: 0.0790
# 3/10, train_loss: 0.0921
# 4/10, train_loss: 0.0549
# 5/10, train_loss: 0.0876
# 6/10, train_loss: 0.0507
# 7/10, train_loss: 0.0742
# 8/10, train_loss: 0.1031
# 9/10, train_loss: 0.0618
# 10/10, train_loss: 0.0826
# Epoch 990 average loss: 0.0752
# Current epoch: 990 current mean dice: 0.8621 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 991/1000
# 1/10, train_loss: 0.0932
# 2/10, train_loss: 0.0827
# 3/10, train_loss: 0.0731
# 4/10, train_loss: 0.1179
# 5/10, train_loss: 0.0534
# 6/10, train_loss: 0.0858
# 7/10, train_loss: 0.0933
# 8/10, train_loss: 0.1384
# 9/10, train_loss: 0.0899
# 10/10, train_loss: 0.0788
# Epoch 991 average loss: 0.0906
# ----------
# Epoch 992/1000
# 1/10, train_loss: 0.0604
# 2/10, train_loss: 0.1202
# 3/10, train_loss: 0.1124
# 4/10, train_loss: 0.1133
# 5/10, train_loss: 0.1494
# 6/10, train_loss: 0.0944
# 7/10, train_loss: 0.0875
# 8/10, train_loss: 0.2931
# 9/10, train_loss: 0.0959
# 10/10, train_loss: 0.0680
# Epoch 992 average loss: 0.1195
# Current epoch: 992 current mean dice: 0.8098 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 993/1000
# 1/10, train_loss: 0.1301
# 2/10, train_loss: 0.0993
# 3/10, train_loss: 0.0772
# 4/10, train_loss: 0.1143
# 5/10, train_loss: 0.0744
# 6/10, train_loss: 0.0711
# 7/10, train_loss: 0.0857
# 8/10, train_loss: 0.0597
# 9/10, train_loss: 0.1521
# 10/10, train_loss: 0.1319
# Epoch 993 average loss: 0.0996
# ----------
# Epoch 994/1000
# 1/10, train_loss: 0.0686
# 2/10, train_loss: 0.0877
# 3/10, train_loss: 0.0518
# 4/10, train_loss: 0.1093
# 5/10, train_loss: 0.0997
# 6/10, train_loss: 0.0778
# 7/10, train_loss: 0.0951
# 8/10, train_loss: 0.0857
# 9/10, train_loss: 0.0877
# 10/10, train_loss: 0.0600
# Epoch 994 average loss: 0.0823
# Current epoch: 994 current mean dice: 0.8514 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 995/1000
# 1/10, train_loss: 0.1345
# 2/10, train_loss: 0.2919
# 3/10, train_loss: 0.0841
# 4/10, train_loss: 0.1126
# 5/10, train_loss: 0.1094
# 6/10, train_loss: 0.0840
# 7/10, train_loss: 0.0744
# 8/10, train_loss: 0.0544
# 9/10, train_loss: 0.2921
# 10/10, train_loss: 0.2785
# Epoch 995 average loss: 0.1516
# ----------
# Epoch 996/1000
# 1/10, train_loss: 0.1176
# 2/10, train_loss: 0.0730
# 3/10, train_loss: 0.0738
# 4/10, train_loss: 0.0892
# 5/10, train_loss: 0.1110
# 6/10, train_loss: 0.1006
# 7/10, train_loss: 0.1014
# 8/10, train_loss: 0.0850
# 9/10, train_loss: 0.0813
# 10/10, train_loss: 0.0672
# Epoch 996 average loss: 0.0900
# Current epoch: 996 current mean dice: 0.8385 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 997/1000
# 1/10, train_loss: 0.0499
# 2/10, train_loss: 0.1035
# 3/10, train_loss: 0.1653
# 4/10, train_loss: 0.0802
# 5/10, train_loss: 0.0827
# 6/10, train_loss: 0.0708
# 7/10, train_loss: 0.0878
# 8/10, train_loss: 0.1323
# 9/10, train_loss: 0.3108
# 10/10, train_loss: 0.0753
# Epoch 997 average loss: 0.1158
# ----------
# Epoch 998/1000
# 1/10, train_loss: 0.1527
# 2/10, train_loss: 0.0724
# 3/10, train_loss: 0.0837
# 4/10, train_loss: 0.0886
# 5/10, train_loss: 0.0944
# 6/10, train_loss: 0.0658
# 7/10, train_loss: 0.1077
# 8/10, train_loss: 0.2857
# 9/10, train_loss: 0.0652
# 10/10, train_loss: 0.0793
# Epoch 998 average loss: 0.1095
# Current epoch: 998 current mean dice: 0.8499 best mean dice: 0.8900 at epoch 764
# ----------
# Epoch 999/1000
# 1/10, train_loss: 0.1141
# 2/10, train_loss: 0.2836
# 3/10, train_loss: 0.0935
# 4/10, train_loss: 0.3051
# 5/10, train_loss: 0.0651
# 6/10, train_loss: 0.0761
# 7/10, train_loss: 0.1210
# 8/10, train_loss: 0.0494
# 9/10, train_loss: 0.1357
# 10/10, train_loss: 0.0622
# Epoch 999 average loss: 0.1306
# ----------
# Epoch 1000/1000
# 1/10, train_loss: 0.0719
# 2/10, train_loss: 0.3239
# 3/10, train_loss: 0.0989
# 4/10, train_loss: 0.0859
# 5/10, train_loss: 0.0692
# 6/10, train_loss: 0.0745
# 7/10, train_loss: 0.0651
# 8/10, train_loss: 0.0956
# 9/10, train_loss: 0.1154
# 10/10, train_loss: 0.0767
# Epoch 1000 average loss: 0.1077
# Current epoch: 1000 current mean dice: 0.8736 best mean dice: 0.8900 at epoch 764
# Training completed, best_metric: 0.8900 at epoch: 764
# <ipython-input-1-229b0c493f6e>:190: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_metric_model.pth'))
# Class 0:
# 	Dice Coefficient = 0.9963
# 	Hausdorff Distance = 23.6909
# 	Volumetric Difference = 0.0018
# Class 1:
# 	Dice Coefficient = 0.8372
# 	Hausdorff Distance = 21.4847
# 	Volumetric Difference = 0.0781
# Class 2:
# 	Dice Coefficient = 0.8845
# 	Hausdorff Distance = 10.7371
# 	Volumetric Difference = 0.0325
# Class 3:
# 	Dice Coefficient = 0.8522
# 	Hausdorff Distance = 11.6964
# 	Volumetric Difference = 0.1046
